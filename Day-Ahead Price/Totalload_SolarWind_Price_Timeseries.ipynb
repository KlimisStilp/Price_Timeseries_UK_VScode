# %% [markdown]
# # Importing Repositories

# %%
import os
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
from scipy import stats
warnings.filterwarnings("ignore")
sns.set_theme(style="darkgrid")
plt.rcParams['figure.figsize']=(20,10)

# %%
def missing_zero_values_table(df):
        ''''Takes a pandas dataframe and returns a statistics table that explains the missing and 
        zero values'''
        zero_val = (df == 0.00).astype(int).sum(axis=0)
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mz_table = pd.concat([zero_val, mis_val, mis_val_percent], axis=1)
        mz_table = mz_table.rename(
        columns = {0 : 'Zero Values', 1 : 'Missing Values', 2 : '% of Total Values'})
        mz_table['Total Zero Missing Values'] = mz_table['Zero Values'] + mz_table['Missing Values']
        mz_table['% Total Zero Missing Values'] = 100 * mz_table['Total Zero Missing Values'] / len(df)
        mz_table['Data Type'] = df.dtypes
        mz_table = mz_table[
            mz_table.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("Our selected dataframe has " + str(df.shape[1]) + " columns and " + str(df.shape[0]) + " Rows.\n"      
            "There are " + str(mz_table.shape[0]) +
              " columns that have missing values.")
    
        return mz_table

# %% [markdown]
# # Importing data files

# %% [markdown]
# ## Paths for files

# %%
path_price = r'C:\Users\2836589S\OneDrive - University of Glasgow\Data\DayAheadPrices_12.1.D'
path_windsolar = r'C:\Users\2836589S\OneDrive - University of Glasgow\Data\DayAheadGenerationForecastForWindAndSolar_14.1.D'

# %% [markdown]
# ## Price Timeseries Importing

# %%
f_price = glob.glob(path_price + "/*.csv")
dprice = [pd.read_csv(f, sep='\t', parse_dates=['DateTime']) for f in f_price]

price_ts = pd.concat(dprice)
price_ts = price_ts[price_ts['AreaCode'] == '10YGB----------A']
price_ts = price_ts[['DateTime', 'Price']]
price_ts.sort_values(by='DateTime', ascending=True)
price_ts.reset_index(drop=True)
price_ts.set_index('DateTime', inplace=True)
price_ts = price_ts.resample('H').fillna('nearest')
price_ts
# Out:
#                      Price
# DateTime
# 2014-12-18 23:00:00  39.91
# 2014-12-19 00:00:00  36.59
# 2014-12-19 01:00:00  31.91
# 2014-12-19 02:00:00  22.53
# 2014-12-19 03:00:00  20.96
# ...                    ...
# 2020-12-31 18:00:00  71.30
# 2020-12-31 19:00:00  61.04
# 2020-12-31 20:00:00  60.39
# 2020-12-31 21:00:00  57.96
# 2020-12-31 22:00:00  55.02
#
# [52920 rows x 1 columns]

# %%
price_ts.to_csv(r'C:\Users\2836589S\OneDrive - University of Glasgow\Data\Data Frames\historic_price.csv')

# %% [markdown]
# ## Wind and Solar Timeseries Importing

# %% [markdown]
# ### Wind Off Shore

# %%
f_windoff = glob.glob(path_windsolar + "/*.csv")
dwindoff = [pd.read_csv(f, sep='\t', parse_dates=['DateTime']) for f in f_windoff]

windoff_ts = pd.concat(dwindoff)
windoff_ts = windoff_ts[windoff_ts['AreaCode'] == '10YGB----------A']
windoff_ts = windoff_ts[windoff_ts['ProductionType'] == 'Wind Offshore']
windoff_ts = windoff_ts[['DateTime', 'AggregatedGenerationForecast']]
windoff_ts.rename(columns={"AggregatedGenerationForecast":"Wind OffGeneration"}, inplace=True)
windoff_ts.sort_values(by='DateTime', ascending=True)
windoff_ts.reset_index(drop=True)
windoff_ts.drop_duplicates(subset=['DateTime'], inplace=True)
windoff_ts.set_index('DateTime', inplace=True)
test = pd.merge(price_ts, windoff_ts, right_index=True, left_index=True)
test = test.asfreq('H')
test.index
# Out:
# DatetimeIndex(['2014-12-30 00:00:00', '2014-12-30 01:00:00',
#                '2014-12-30 02:00:00', '2014-12-30 03:00:00',
#                '2014-12-30 04:00:00', '2014-12-30 05:00:00',
#                '2014-12-30 06:00:00', '2014-12-30 07:00:00',
#                '2014-12-30 08:00:00', '2014-12-30 09:00:00',
#                ...
#                '2020-12-31 13:00:00', '2020-12-31 14:00:00',
#                '2020-12-31 15:00:00', '2020-12-31 16:00:00',
#                '2020-12-31 17:00:00', '2020-12-31 18:00:00',
#                '2020-12-31 19:00:00', '2020-12-31 20:00:00',
#                '2020-12-31 21:00:00', '2020-12-31 22:00:00'],
#               dtype='datetime64[ns]', name='DateTime', length=52655, freq='H')

# %% [markdown]
# ### Wind On Shore Data

# %%
f_windon = glob.glob(path_windsolar + "/*.csv")
dwindon = [pd.read_csv(f, sep='\t', parse_dates=['DateTime']) for f in f_windon]

windon_ts = pd.concat(dwindon)
windon_ts = windon_ts[windon_ts['AreaCode'] == '10YGB----------A']
windon_ts = windon_ts[windon_ts['ProductionType'] == 'Wind Onshore']
windon_ts = windon_ts[['DateTime', 'AggregatedGenerationForecast']]
windon_ts.rename(columns={"AggregatedGenerationForecast":"Wind OnGeneration"}, inplace=True)
windon_ts.sort_values(by='DateTime', ascending=True)
windon_ts.reset_index(drop=True)
windon_ts.drop_duplicates(subset=['DateTime'], inplace=True)
windon_ts.set_index('DateTime', inplace=True)
test = pd.merge(test, windon_ts, right_index=True, left_index=True)

# %% [markdown]
# ### Solar Data

# %%
f_solar = glob.glob(path_windsolar + "/*.csv")
dsolar = [pd.read_csv(f, sep='\t', parse_dates=['DateTime']) for f in f_solar]

solar_ts = pd.concat(dsolar)
solar_ts = solar_ts[solar_ts['AreaCode'] == '10YGB----------A']
solar_ts = solar_ts[solar_ts['ProductionType'] == 'Solar']
solar_ts = solar_ts[['DateTime', 'AggregatedGenerationForecast']]
solar_ts.rename(columns={"AggregatedGenerationForecast":"Solar Generation"}, inplace=True)
solar_ts.sort_values(by='DateTime', ascending=True)
solar_ts.reset_index(drop=True)
solar_ts.drop_duplicates(subset=['DateTime'], inplace=True)
solar_ts.set_index('DateTime', inplace=True)
test = pd.merge(test, solar_ts, right_index=True, left_index=True)

# %% [markdown]
# ### Demand Data

# %%
ddemand = pd.read_csv(r'C:\Users\2836589S\OneDrive - University of Glasgow\Data\Data Frames\demandto2020.csv',
                       parse_dates=['time'])
demand_ts = ddemand[['time', 'ND']]
demand_ts.rename(columns={"time":"DateTime",
                          "ND":"Demand"}, inplace=True)

demand_ts.sort_values(by='DateTime', ascending=True)
demand_ts.reset_index(drop=True, inplace=True)
demand_ts.set_index('DateTime', inplace=True)
demand_ts = demand_ts.resample('H').sum()
df_model = pd.merge(test, demand_ts, right_index=True, left_index=True)

# %%
df_model
# Out:
#                      Price  Wind OffGeneration  Wind OnGeneration  \
# DateTime
# 2014-12-30 00:00:00  42.97              996.58            2363.80
# 2014-12-30 01:00:00  40.13             1059.20            2413.88
# 2014-12-30 02:00:00  36.90             1123.27            2450.75
# 2014-12-30 03:00:00  34.98             1177.54            2500.78
# 2014-12-30 04:00:00  33.63             1188.21            2536.07
# ...                    ...                 ...                ...
# 2020-12-31 18:00:00  71.30             2644.97            3028.41
# 2020-12-31 19:00:00  61.04             2707.55            3046.72
# 2020-12-31 20:00:00  60.39             2695.01            3053.60
# 2020-12-31 21:00:00  57.96             2829.57            3086.61
# 2020-12-31 22:00:00  55.02             2886.83            3116.99
#
#                      Solar Generation  Demand
# DateTime
# 2014-12-30 00:00:00               0.0   63271
# 2014-12-30 01:00:00               0.0   60951
# 2014-12-30 02:00:00               0.0   59496
# 2014-12-30 03:00:00               0.0   57390
# 2014-12-30 04:00:00               0.0   55862
# ...                               ...     ...
# 2020-12-31 18:00:00               0.0   85279
# 2020-12-31 19:00:00               0.0   83146
# 2020-12-31 20:00:00               0.0   77395
# 2020-12-31 21:00:00               0.0   71666
# 2020-12-31 22:00:00               0.0   66053
#
# [52631 rows x 5 columns]

# %%
df_model.index
# Out:
# DatetimeIndex(['2014-12-30 00:00:00', '2014-12-30 01:00:00',
#                '2014-12-30 02:00:00', '2014-12-30 03:00:00',
#                '2014-12-30 04:00:00', '2014-12-30 05:00:00',
#                '2014-12-30 06:00:00', '2014-12-30 07:00:00',
#                '2014-12-30 08:00:00', '2014-12-30 09:00:00',
#                ...
#                '2020-12-31 13:00:00', '2020-12-31 14:00:00',
#                '2020-12-31 15:00:00', '2020-12-31 16:00:00',
#                '2020-12-31 17:00:00', '2020-12-31 18:00:00',
#                '2020-12-31 19:00:00', '2020-12-31 20:00:00',
#                '2020-12-31 21:00:00', '2020-12-31 22:00:00'],
#               dtype='datetime64[ns]', name='DateTime', length=52631, freq=None)

# %%
df_model =  df_model.resample('H').fillna('nearest')

# %% [markdown]
# ## Transforming Solar, Wind Onshore and Wind Offshore Generation values

# %%
# Apply square root transformation to our predictors in order to have the scale with our dependent variable (Price)

# df_model['Solar Generation'] = df_model['Solar Generation'].transform('sqrt')
# df_model['Wind OffGeneration'] = df_model['Wind OffGeneration'].transform('sqrt')
# df_model['Wind OnGeneration'] = df_model['Wind OnGeneration'].transform('sqrt')
# df_model['Demand'] = df_model['Demand'].transform('sqrt')
df_model
# Out:
#                      Price  Wind OffGeneration  Wind OnGeneration  \
# DateTime
# 2014-12-30 00:00:00  42.97              996.58            2363.80
# 2014-12-30 01:00:00  40.13             1059.20            2413.88
# 2014-12-30 02:00:00  36.90             1123.27            2450.75
# 2014-12-30 03:00:00  34.98             1177.54            2500.78
# 2014-12-30 04:00:00  33.63             1188.21            2536.07
# ...                    ...                 ...                ...
# 2020-12-31 18:00:00  71.30             2644.97            3028.41
# 2020-12-31 19:00:00  61.04             2707.55            3046.72
# 2020-12-31 20:00:00  60.39             2695.01            3053.60
# 2020-12-31 21:00:00  57.96             2829.57            3086.61
# 2020-12-31 22:00:00  55.02             2886.83            3116.99
#
#                      Solar Generation  Demand
# DateTime
# 2014-12-30 00:00:00               0.0   63271
# 2014-12-30 01:00:00               0.0   60951
# 2014-12-30 02:00:00               0.0   59496
# 2014-12-30 03:00:00               0.0   57390
# 2014-12-30 04:00:00               0.0   55862
# ...                               ...     ...
# 2020-12-31 18:00:00               0.0   85279
# 2020-12-31 19:00:00               0.0   83146
# 2020-12-31 20:00:00               0.0   77395
# 2020-12-31 21:00:00               0.0   71666
# 2020-12-31 22:00:00               0.0   66053
#
# [52655 rows x 5 columns]

# %%
import matplotlib.dates as mdates


fig, ax = plt.subplots(figsize=(14, 6))
sns.lineplot(x=df_model.index, y=df_model['Price'], ax=ax)
month_locator = mdates.MonthLocator(interval=1)
year_month_formatter = mdates.DateFormatter("%Y-%m")
ax.xaxis.set_major_locator(month_locator)
ax.xaxis.set_major_formatter(year_month_formatter)
plt.xticks(rotation=90)
plt.title('Price Timeseries')
# plt.savefig(r'C:\Users\2836589S\OneDrive - University of Glasgow\VScode Projects\Price Timeseries UK\Plots\Timeseries Plots\price_timeseries.png')
# Out:
# Text(0.5, 1.0, 'Price Timeseries')

# %%
sns.lineplot(x=df_model.index, y=df_model['Solar Generation'])
plt.title('Solar Generation Timeseries')
# plt.savefig(r'C:\Users\2836589S\OneDrive - University of Glasgow\VScode Projects\Price Timeseries UK\Plots\Timeseries Plots\solar_timeseries.png')
# Out:
# Text(0.5, 1.0, 'Solar Generation Timeseries')

# %%
sns.lineplot(x=df_model.index, y=df_model['Wind OffGeneration'])
plt.title('Wind Offshore Generation Timeseries')
# plt.savefig(r'C:\Users\2836589S\OneDrive - University of Glasgow\VScode Projects\Price Timeseries UK\Plots\Timeseries Plots\windoff_timeseries.png')
# Out:
# Text(0.5, 1.0, 'Wind Offshore Generation Timeseries')

# %%
sns.lineplot(x=df_model.index, y=df_model['Wind OnGeneration'])
plt.title('Wind Onshore Generation Timeseries')
# plt.savefig(r'C:\Users\2836589S\OneDrive - University of Glasgow\VScode Projects\Price Timeseries UK\Plots\Timeseries Plots\windon_timeseries.png')
# Out:
# Text(0.5, 1.0, 'Wind Onshore Generation Timeseries')

# %%
sns.lineplot(x=df_model.index, y=df_model['Demand'])
plt.title('Demand Timeseries')
# # plt.savefig(r'C:\Users\2836589S\OneDrive - University of Glasgow\VScode Projects\Price Timeseries UK\Plots\Timeseries Plots\demand_timeseries.png')
# Out:
# Text(0.5, 1.0, 'Demand Timeseries')

# %%
# Selecting the timeseries we will study further on.

df_model = df_model.loc['2016-12-1':'2020-09-30']

# %% [markdown]
# # Creating lags - 1-week-lags

# %%
def lag_col(df, variable, lags):
    '''
        Takes in a pandas dataframe, a specific variable of the dataset and number of lags as a list
        and returns the df updated with the lags of the variable
        
        Parameters:
            df: pandas dataframe
            variable: string
            lags: list
        
        Returns:
            Adds column for every lag inside the list for our designated variable
        
        '''


    for lag in lags:
        df[str(variable) + '_' + str(lag)] = df[variable].shift(lag)
    return df

# %%
lags = list(range(1,168)) # 1-week-lags

# %%
lag_col(df_model, 'Price', lags)

# Bellow are lines that create lags on the other covariates

# lag_col(df_model, 'Solar Generation', lags)
# lag_col(df_model, 'Wind OffGeneration', lags)
# lag_col(df_model, 'Wind OnGeneration', lags)
# lag_col(df_model, 'Demand', lags)
# Out:
#                      Price  Wind OffGeneration  Wind OnGeneration  \
# DateTime
# 2016-12-01 00:00:00  45.01             1449.06            3723.76
# 2016-12-01 01:00:00  42.09             1565.10            3775.25
# 2016-12-01 02:00:00  39.59             1605.00            3817.50
# 2016-12-01 03:00:00  37.94             1628.37            3895.91
# 2016-12-01 04:00:00  36.79             1636.05            3918.80
# ...                    ...                 ...                ...
# 2020-09-30 19:00:00  46.55             7773.13            2859.31
# 2020-09-30 20:00:00  40.95             7812.94            2772.00
# 2020-09-30 21:00:00  34.84             7679.28            2653.40
# 2020-09-30 22:00:00  37.44             7322.34            2423.10
# 2020-09-30 23:00:00  31.93             7085.62            2347.03
#
#                      Solar Generation  Demand  Price_1  Price_2  Price_3  \
# DateTime
# 2016-12-01 00:00:00               0.0   62887      NaN      NaN      NaN
# 2016-12-01 01:00:00               0.0   60602    45.01      NaN      NaN
# 2016-12-01 02:00:00               0.0   59697    42.09    45.01      NaN
# 2016-12-01 03:00:00               0.0   58078    39.59    42.09    45.01
# 2016-12-01 04:00:00               0.0   56809    37.94    39.59    42.09
# ...                               ...     ...      ...      ...      ...
# 2020-09-30 19:00:00               0.0   72085    59.49    67.72    56.82
# 2020-09-30 20:00:00               0.0   67465    46.55    59.49    67.72
# 2020-09-30 21:00:00               0.0   61393    40.95    46.55    59.49
# 2020-09-30 22:00:00               0.0   54178    34.84    40.95    46.55
# 2020-09-30 23:00:00               0.0   47419    37.44    34.84    40.95
#
#                      Price_4  Price_5  ...  Price_158  Price_159  Price_160  \
# DateTime                               ...
# 2016-12-01 00:00:00      NaN      NaN  ...        NaN        NaN        NaN
# 2016-12-01 01:00:00      NaN      NaN  ...        NaN        NaN        NaN
# 2016-12-01 02:00:00      NaN      NaN  ...        NaN        NaN        NaN
# 2016-12-01 03:00:00      NaN      NaN  ...        NaN        NaN        NaN
# 2016-12-01 04:00:00    45.01      NaN  ...        NaN        NaN        NaN
# ...                      ...      ...  ...        ...        ...        ...
# 2020-09-30 19:00:00    50.12    43.70  ...      48.09      39.73      31.41
# 2020-09-30 20:00:00    56.82    50.12  ...      48.58      48.09      39.73
# 2020-09-30 21:00:00    67.72    56.82  ...      49.88      48.58      48.09
# 2020-09-30 22:00:00    59.49    67.72  ...      47.23      49.88      48.58
# 2020-09-30 23:00:00    46.55    59.49  ...      44.56      47.23      49.88
#
#                      Price_161  Price_162  Price_163  Price_164  Price_165  \
# DateTime
# 2016-12-01 00:00:00        NaN        NaN        NaN        NaN        NaN
# 2016-12-01 01:00:00        NaN        NaN        NaN        NaN        NaN
# 2016-12-01 02:00:00        NaN        NaN        NaN        NaN        NaN
# 2016-12-01 03:00:00        NaN        NaN        NaN        NaN        NaN
# 2016-12-01 04:00:00        NaN        NaN        NaN        NaN        NaN
# ...                        ...        ...        ...        ...        ...
# 2020-09-30 19:00:00      26.98      29.27      33.02      34.98      39.09
# 2020-09-30 20:00:00      31.41      26.98      29.27      33.02      34.98
# 2020-09-30 21:00:00      39.73      31.41      26.98      29.27      33.02
# 2020-09-30 22:00:00      48.09      39.73      31.41      26.98      29.27
# 2020-09-30 23:00:00      48.58      48.09      39.73      31.41      26.98
#
#                      Price_166  Price_167
# DateTime
# 2016-12-01 00:00:00        NaN        NaN
# 2016-12-01 01:00:00        NaN        NaN
# 2016-12-01 02:00:00        NaN        NaN
# 2016-12-01 03:00:00        NaN        NaN
# 2016-12-01 04:00:00        NaN        NaN
# ...                        ...        ...
# 2020-09-30 19:00:00      37.42      41.52
# 2020-09-30 20:00:00      39.09      37.42
# 2020-09-30 21:00:00      34.98      39.09
# 2020-09-30 22:00:00      33.02      34.98
# 2020-09-30 23:00:00      29.27      33.02
#
# [33600 rows x 172 columns]

# %%
missing_zero_values_table(df_model)
# Out:
# Our selected dataframe has 172 columns and 33600 Rows.
# There are 167 columns that have missing values.
#            Zero Values  Missing Values  % of Total Values  \
# Price_167            9             167                0.5
# Price_166            9             166                0.5
# Price_165            9             165                0.5
# Price_164            9             164                0.5
# Price_163            9             163                0.5
# ...                ...             ...                ...
# Price_5              9               5                0.0
# Price_4              9               4                0.0
# Price_3              9               3                0.0
# Price_2              9               2                0.0
# Price_1              9               1                0.0
#
#            Total Zero Missing Values  % Total Zero Missing Values Data Type
# Price_167                        176                          0.5   float64
# Price_166                        175                          0.5   float64
# Price_165                        174                          0.5   float64
# Price_164                        173                          0.5   float64
# Price_163                        172                          0.5   float64
# ...                              ...                          ...       ...
# Price_5                           14                          0.0   float64
# Price_4                           13                          0.0   float64
# Price_3                           12                          0.0   float64
# Price_2                           11                          0.0   float64
# Price_1                           10                          0.0   float64
#
# [167 rows x 6 columns]

# %%
# We are losing 167 hours, so these will be the first two weeks of December 2016

# %%
# Extracting the hours in a seperate column

df_model['Hour'] = df_model.index.hour
df_model
# Out:
#                      Price  Wind OffGeneration  Wind OnGeneration  \
# DateTime
# 2016-12-01 00:00:00  45.01             1449.06            3723.76
# 2016-12-01 01:00:00  42.09             1565.10            3775.25
# 2016-12-01 02:00:00  39.59             1605.00            3817.50
# 2016-12-01 03:00:00  37.94             1628.37            3895.91
# 2016-12-01 04:00:00  36.79             1636.05            3918.80
# ...                    ...                 ...                ...
# 2020-09-30 19:00:00  46.55             7773.13            2859.31
# 2020-09-30 20:00:00  40.95             7812.94            2772.00
# 2020-09-30 21:00:00  34.84             7679.28            2653.40
# 2020-09-30 22:00:00  37.44             7322.34            2423.10
# 2020-09-30 23:00:00  31.93             7085.62            2347.03
#
#                      Solar Generation  Demand  Price_1  Price_2  Price_3  \
# DateTime
# 2016-12-01 00:00:00               0.0   62887      NaN      NaN      NaN
# 2016-12-01 01:00:00               0.0   60602    45.01      NaN      NaN
# 2016-12-01 02:00:00               0.0   59697    42.09    45.01      NaN
# 2016-12-01 03:00:00               0.0   58078    39.59    42.09    45.01
# 2016-12-01 04:00:00               0.0   56809    37.94    39.59    42.09
# ...                               ...     ...      ...      ...      ...
# 2020-09-30 19:00:00               0.0   72085    59.49    67.72    56.82
# 2020-09-30 20:00:00               0.0   67465    46.55    59.49    67.72
# 2020-09-30 21:00:00               0.0   61393    40.95    46.55    59.49
# 2020-09-30 22:00:00               0.0   54178    34.84    40.95    46.55
# 2020-09-30 23:00:00               0.0   47419    37.44    34.84    40.95
#
#                      Price_4  Price_5  ...  Price_159  Price_160  Price_161  \
# DateTime                               ...
# 2016-12-01 00:00:00      NaN      NaN  ...        NaN        NaN        NaN
# 2016-12-01 01:00:00      NaN      NaN  ...        NaN        NaN        NaN
# 2016-12-01 02:00:00      NaN      NaN  ...        NaN        NaN        NaN
# 2016-12-01 03:00:00      NaN      NaN  ...        NaN        NaN        NaN
# 2016-12-01 04:00:00    45.01      NaN  ...        NaN        NaN        NaN
# ...                      ...      ...  ...        ...        ...        ...
# 2020-09-30 19:00:00    50.12    43.70  ...      39.73      31.41      26.98
# 2020-09-30 20:00:00    56.82    50.12  ...      48.09      39.73      31.41
# 2020-09-30 21:00:00    67.72    56.82  ...      48.58      48.09      39.73
# 2020-09-30 22:00:00    59.49    67.72  ...      49.88      48.58      48.09
# 2020-09-30 23:00:00    46.55    59.49  ...      47.23      49.88      48.58
#
#                      Price_162  Price_163  Price_164  Price_165  Price_166  \
# DateTime
# 2016-12-01 00:00:00        NaN        NaN        NaN        NaN        NaN
# 2016-12-01 01:00:00        NaN        NaN        NaN        NaN        NaN
# 2016-12-01 02:00:00        NaN        NaN        NaN        NaN        NaN
# 2016-12-01 03:00:00        NaN        NaN        NaN        NaN        NaN
# 2016-12-01 04:00:00        NaN        NaN        NaN        NaN        NaN
# ...                        ...        ...        ...        ...        ...
# 2020-09-30 19:00:00      29.27      33.02      34.98      39.09      37.42
# 2020-09-30 20:00:00      26.98      29.27      33.02      34.98      39.09
# 2020-09-30 21:00:00      31.41      26.98      29.27      33.02      34.98
# 2020-09-30 22:00:00      39.73      31.41      26.98      29.27      33.02
# 2020-09-30 23:00:00      48.09      39.73      31.41      26.98      29.27
#
#                      Price_167  Hour
# DateTime
# 2016-12-01 00:00:00        NaN     0
# 2016-12-01 01:00:00        NaN     1
# 2016-12-01 02:00:00        NaN     2
# 2016-12-01 03:00:00        NaN     3
# 2016-12-01 04:00:00        NaN     4
# ...                        ...   ...
# 2020-09-30 19:00:00      41.52    19
# 2020-09-30 20:00:00      37.42    20
# 2020-09-30 21:00:00      39.09    21
# 2020-09-30 22:00:00      34.98    22
# 2020-09-30 23:00:00      33.02    23
#
# [33600 rows x 173 columns]

# %%
df_model.dropna(inplace=True) # Clearing na values

# %% [markdown]
# # Re-forming our dataset

# %% [markdown]
# ## Creating single-hour data blocks

# %%
#Create multi-dataframe that will have every single dataset regarding the time of the day

hours = df_model['Hour'].unique().tolist()
hours.sort()
df_hour ={hour: pd.DataFrame() for hour in hours}
for i in range(len(hours)):
    df_hour[i] = df_model[df_model['Hour'] == i]
    


# Example of the dataset of 00:00    
df_hour[1]
# Out:
#                      Price  Wind OffGeneration  Wind OnGeneration  \
# DateTime
# 2016-12-08 01:00:00  36.25             2986.97            4590.27
# 2016-12-09 01:00:00  37.33              989.59            2440.66
# 2016-12-10 01:00:00  40.26             2705.68            4038.47
# 2016-12-11 01:00:00  38.59             2073.47            4114.45
# 2016-12-12 01:00:00  37.02              429.59            1246.44
# ...                    ...                 ...                ...
# 2020-09-26 01:00:00  23.23             8847.27            4908.71
# 2020-09-27 01:00:00  13.69             7654.24            2511.73
# 2020-09-28 01:00:00  26.77             4323.23            1391.80
# 2020-09-29 01:00:00  32.54              903.32            1175.29
# 2020-09-30 01:00:00  35.33             2381.07            4658.24
#
#                      Solar Generation  Demand  Price_1  Price_2  Price_3  \
# DateTime
# 2016-12-08 01:00:00               0.0   54646    37.76    37.92    36.46
# 2016-12-09 01:00:00               0.0   56597    40.44    40.87    36.07
# 2016-12-10 01:00:00               0.0   54862    40.25    43.58    34.24
# 2016-12-11 01:00:00               0.0   53397    40.93    42.07    36.08
# 2016-12-12 01:00:00               0.0   55787    37.34    37.41    40.09
# ...                               ...     ...      ...      ...      ...
# 2020-09-26 01:00:00               0.0   38228    26.20    28.71    31.80
# 2020-09-27 01:00:00               0.0   38205    16.95    18.77    35.13
# 2020-09-28 01:00:00               0.0   41959    27.61    28.85    31.38
# 2020-09-29 01:00:00               0.0   43623    34.37    36.10    37.54
# 2020-09-30 01:00:00               0.0   41057    38.83    40.25    47.13
#
#                      Price_4  Price_5  ...  Price_159  Price_160  Price_161  \
# DateTime                               ...
# 2016-12-08 01:00:00    38.20    48.32  ...      52.44      55.97      55.01
# 2016-12-09 01:00:00    42.06    48.34  ...      58.58      64.88      69.36
# 2016-12-10 01:00:00    35.94    43.98  ...      53.24      57.55      51.31
# 2016-12-11 01:00:00    41.93    44.72  ...      41.30      39.56      38.08
# 2016-12-12 01:00:00    49.93    49.90  ...      53.80      54.80      54.50
# ...                      ...      ...  ...        ...        ...        ...
# 2020-09-26 01:00:00    33.14    42.97  ...      37.03      36.96      40.00
# 2020-09-27 01:00:00    38.00    44.94  ...      48.17      43.60      45.00
# 2020-09-28 01:00:00    36.65    41.23  ...      58.85      62.37      61.06
# 2020-09-29 01:00:00    37.44    43.19  ...      37.51      42.00      52.85
# 2020-09-30 01:00:00    41.43    47.90  ...      50.36      54.13      52.73
#
#                      Price_162  Price_163  Price_164  Price_165  Price_166  \
# DateTime
# 2016-12-08 01:00:00      51.65      41.96      38.04      36.79      37.94
# 2016-12-09 01:00:00      55.51      40.99      39.50      39.01      39.09
# 2016-12-10 01:00:00      41.02      39.99      38.61      38.08      39.94
# 2016-12-11 01:00:00      36.49      35.00      31.43      30.45      34.25
# 2016-12-12 01:00:00      55.61      54.31      37.18      36.34      31.58
# ...                        ...        ...        ...        ...        ...
# 2020-09-26 01:00:00      38.75      37.42      34.60      32.06      28.73
# 2020-09-27 01:00:00      36.00      32.79      32.28      32.54      31.99
# 2020-09-28 01:00:00      67.43      75.86      52.10      45.76      36.95
# 2020-09-29 01:00:00      57.00      65.60      48.02      38.03      37.06
# 2020-09-30 01:00:00      54.40      52.18      47.61      39.85      35.22
#
#                      Price_167  Hour
# DateTime
# 2016-12-08 01:00:00      39.59     1
# 2016-12-09 01:00:00      40.48     1
# 2016-12-10 01:00:00      40.29     1
# 2016-12-11 01:00:00      38.00     1
# 2016-12-12 01:00:00      32.36     1
# ...                        ...   ...
# 2020-09-26 01:00:00      29.21     1
# 2020-09-27 01:00:00      32.00     1
# 2020-09-28 01:00:00      30.03     1
# 2020-09-29 01:00:00      35.90     1
# 2020-09-30 01:00:00      32.63     1
#
# [1393 rows x 173 columns]

# %%
for h in hours:
    for i in range(1,h+1):
        df_hour[h].drop(columns=['Price_'+str(i)], inplace=True)

# %%
for h in hours:
    df_hour[h].rename(columns={'Price_'+str(h+1):'Price_Recent'}, inplace=True)

# %%
df_hour[0]
# Out:
#             Price  Wind OffGeneration  Wind OnGeneration  Solar Generation  \
# DateTime
# 2016-12-08  37.76             3192.99            4746.20               0.0
# 2016-12-09  40.44              953.12            2308.48               0.0
# 2016-12-10  40.25             2944.11            4100.36               0.0
# 2016-12-11  40.93             1974.59            3983.59               0.0
# 2016-12-12  37.34              540.73            1150.81               0.0
# ...           ...                 ...                ...               ...
# 2020-09-26  26.20             8836.53            4958.44               0.0
# 2020-09-27  16.95             7790.02            2687.13               0.0
# 2020-09-28  27.61             4389.08            1218.13               0.0
# 2020-09-29  34.37              950.22            1327.84               0.0
# 2020-09-30  38.83             1970.02            4216.08               0.0
#
#             Demand  Price_Recent  Price_2  Price_3  Price_4  Price_5  ...  \
# DateTime                                                              ...
# 2016-12-08   56426         37.92    36.46    38.20    48.32    56.22  ...
# 2016-12-09   58924         40.87    36.07    42.06    48.34    54.94  ...
# 2016-12-10   56467         43.58    34.24    35.94    43.98    49.46  ...
# 2016-12-11   55111         42.07    36.08    41.93    44.72    49.78  ...
# 2016-12-12   57390         37.41    40.09    49.93    49.90    55.77  ...
# ...            ...           ...      ...      ...      ...      ...  ...
# 2020-09-26   39535         28.71    31.80    33.14    42.97    54.00  ...
# 2020-09-27   39331         18.77    35.13    38.00    44.94    51.04  ...
# 2020-09-28   42603         28.85    31.38    36.65    41.23    50.00  ...
# 2020-09-29   44401         36.10    37.54    37.44    43.19    49.23  ...
# 2020-09-30   42467         40.25    47.13    41.43    47.90    53.78  ...
#
#             Price_159  Price_160  Price_161  Price_162  Price_163  Price_164  \
# DateTime
# 2016-12-08      55.97      55.01      51.65      41.96      38.04      36.79
# 2016-12-09      64.88      69.36      55.51      40.99      39.50      39.01
# 2016-12-10      57.55      51.31      41.02      39.99      38.61      38.08
# 2016-12-11      39.56      38.08      36.49      35.00      31.43      30.45
# 2016-12-12      54.80      54.50      55.61      54.31      37.18      36.34
# ...               ...        ...        ...        ...        ...        ...
# 2020-09-26      36.96      40.00      38.75      37.42      34.60      32.06
# 2020-09-27      43.60      45.00      36.00      32.79      32.28      32.54
# 2020-09-28      62.37      61.06      67.43      75.86      52.10      45.76
# 2020-09-29      42.00      52.85      57.00      65.60      48.02      38.03
# 2020-09-30      54.13      52.73      54.40      52.18      47.61      39.85
#
#             Price_165  Price_166  Price_167  Hour
# DateTime
# 2016-12-08      37.94      39.59      42.09     0
# 2016-12-09      39.09      40.48      42.41     0
# 2016-12-10      39.94      40.29      42.07     0
# 2016-12-11      34.25      38.00      40.34     0
# 2016-12-12      31.58      32.36      36.14     0
# ...               ...        ...        ...   ...
# 2020-09-26      28.73      29.21      29.80     0
# 2020-09-27      31.99      32.00      32.17     0
# 2020-09-28      36.95      30.03      31.02     0
# 2020-09-29      37.06      35.90      35.90     0
# 2020-09-30      35.22      32.63      33.70     0
#
# [1393 rows x 173 columns]

# %%
# Dropping unwanted features for every single dataset and dropping the nan values
for i in range(len(hours)):
    df_hour[i].drop(columns=['Hour'], inplace=True)

# Example of data frame regarding the 23:00 data frame
df_hour[23]
# Out:
#                      Price  Wind OffGeneration  Wind OnGeneration  \
# DateTime
# 2016-12-07 23:00:00  37.92             3532.74            5138.59
# 2016-12-08 23:00:00  40.87             1207.81            2616.05
# 2016-12-09 23:00:00  43.58             3029.14            4544.63
# 2016-12-10 23:00:00  42.07             2324.71            4229.84
# 2016-12-11 23:00:00  37.41              530.54            1194.77
# ...                    ...                 ...                ...
# 2020-09-26 23:00:00  18.77             8299.65            3305.54
# 2020-09-27 23:00:00  28.85             4662.25            1068.88
# 2020-09-28 23:00:00  36.10             1272.34            1488.26
# 2020-09-29 23:00:00  40.25             1317.64            3139.20
# 2020-09-30 23:00:00  31.93             7085.62            2347.03
#
#                      Solar Generation  Demand  Price_Recent  Price_25  \
# DateTime
# 2016-12-07 23:00:00               0.0   63662         39.91     37.94
# 2016-12-08 23:00:00               0.0   66323         37.92     36.46
# 2016-12-09 23:00:00               0.0   62383         40.87     36.07
# 2016-12-10 23:00:00               0.0   60608         43.58     34.24
# 2016-12-11 23:00:00               0.0   64631         42.07     36.08
# ...                               ...     ...           ...       ...
# 2020-09-26 23:00:00               0.0   43163         28.71     31.80
# 2020-09-27 23:00:00               0.0   46340         18.77     35.13
# 2020-09-28 23:00:00               0.0   48171         28.85     31.38
# 2020-09-29 23:00:00               0.0   46729         36.10     37.54
# 2020-09-30 23:00:00               0.0   47419         40.25     47.13
#
#                      Price_26  Price_27  Price_28  ...  Price_158  Price_159  \
# DateTime                                           ...
# 2016-12-07 23:00:00     40.62     48.99     57.42  ...      55.97      55.01
# 2016-12-08 23:00:00     38.20     48.32     56.22  ...      64.88      69.36
# 2016-12-09 23:00:00     42.06     48.34     54.94  ...      57.55      51.31
# 2016-12-10 23:00:00     35.94     43.98     49.46  ...      39.56      38.08
# 2016-12-11 23:00:00     41.93     44.72     49.78  ...      54.80      54.50
# ...                       ...       ...       ...  ...        ...        ...
# 2020-09-26 23:00:00     33.14     42.97     54.00  ...      43.60      45.00
# 2020-09-27 23:00:00     38.00     44.94     51.04  ...      62.37      61.06
# 2020-09-28 23:00:00     36.65     41.23     50.00  ...      42.00      52.85
# 2020-09-29 23:00:00     37.44     43.19     49.23  ...      54.13      52.73
# 2020-09-30 23:00:00     41.43     47.90     53.78  ...      44.56      47.23
#
#                      Price_160  Price_161  Price_162  Price_163  Price_164  \
# DateTime
# 2016-12-07 23:00:00      51.65      41.96      38.04      36.79      37.94
# 2016-12-08 23:00:00      55.51      40.99      39.50      39.01      39.09
# 2016-12-09 23:00:00      41.02      39.99      38.61      38.08      39.94
# 2016-12-10 23:00:00      36.49      35.00      31.43      30.45      34.25
# 2016-12-11 23:00:00      55.61      54.31      37.18      36.34      31.58
# ...                        ...        ...        ...        ...        ...
# 2020-09-26 23:00:00      36.00      32.79      32.28      32.54      31.99
# 2020-09-27 23:00:00      67.43      75.86      52.10      45.76      36.95
# 2020-09-28 23:00:00      57.00      65.60      48.02      38.03      37.06
# 2020-09-29 23:00:00      54.40      52.18      47.61      39.85      35.22
# 2020-09-30 23:00:00      49.88      48.58      48.09      39.73      31.41
#
#                      Price_165  Price_166  Price_167
# DateTime
# 2016-12-07 23:00:00      39.59      42.09      45.01
# 2016-12-08 23:00:00      40.48      42.41      44.56
# 2016-12-09 23:00:00      40.29      42.07      48.97
# 2016-12-10 23:00:00      38.00      40.34      51.00
# 2016-12-11 23:00:00      32.36      36.14      37.43
# ...                        ...        ...        ...
# 2020-09-26 23:00:00      32.00      32.17      33.08
# 2020-09-27 23:00:00      30.03      31.02      33.30
# 2020-09-28 23:00:00      35.90      35.90      37.10
# 2020-09-29 23:00:00      32.63      33.70      34.77
# 2020-09-30 23:00:00      26.98      29.27      33.02
#
# [1394 rows x 149 columns]

# %%
df_hour[0]
# Out:
#             Price  Wind OffGeneration  Wind OnGeneration  Solar Generation  \
# DateTime
# 2016-12-08  37.76             3192.99            4746.20               0.0
# 2016-12-09  40.44              953.12            2308.48               0.0
# 2016-12-10  40.25             2944.11            4100.36               0.0
# 2016-12-11  40.93             1974.59            3983.59               0.0
# 2016-12-12  37.34              540.73            1150.81               0.0
# ...           ...                 ...                ...               ...
# 2020-09-26  26.20             8836.53            4958.44               0.0
# 2020-09-27  16.95             7790.02            2687.13               0.0
# 2020-09-28  27.61             4389.08            1218.13               0.0
# 2020-09-29  34.37              950.22            1327.84               0.0
# 2020-09-30  38.83             1970.02            4216.08               0.0
#
#             Demand  Price_Recent  Price_2  Price_3  Price_4  Price_5  ...  \
# DateTime                                                              ...
# 2016-12-08   56426         37.92    36.46    38.20    48.32    56.22  ...
# 2016-12-09   58924         40.87    36.07    42.06    48.34    54.94  ...
# 2016-12-10   56467         43.58    34.24    35.94    43.98    49.46  ...
# 2016-12-11   55111         42.07    36.08    41.93    44.72    49.78  ...
# 2016-12-12   57390         37.41    40.09    49.93    49.90    55.77  ...
# ...            ...           ...      ...      ...      ...      ...  ...
# 2020-09-26   39535         28.71    31.80    33.14    42.97    54.00  ...
# 2020-09-27   39331         18.77    35.13    38.00    44.94    51.04  ...
# 2020-09-28   42603         28.85    31.38    36.65    41.23    50.00  ...
# 2020-09-29   44401         36.10    37.54    37.44    43.19    49.23  ...
# 2020-09-30   42467         40.25    47.13    41.43    47.90    53.78  ...
#
#             Price_158  Price_159  Price_160  Price_161  Price_162  Price_163  \
# DateTime
# 2016-12-08      52.44      55.97      55.01      51.65      41.96      38.04
# 2016-12-09      58.58      64.88      69.36      55.51      40.99      39.50
# 2016-12-10      53.24      57.55      51.31      41.02      39.99      38.61
# 2016-12-11      41.30      39.56      38.08      36.49      35.00      31.43
# 2016-12-12      53.80      54.80      54.50      55.61      54.31      37.18
# ...               ...        ...        ...        ...        ...        ...
# 2020-09-26      37.03      36.96      40.00      38.75      37.42      34.60
# 2020-09-27      48.17      43.60      45.00      36.00      32.79      32.28
# 2020-09-28      58.85      62.37      61.06      67.43      75.86      52.10
# 2020-09-29      37.51      42.00      52.85      57.00      65.60      48.02
# 2020-09-30      50.36      54.13      52.73      54.40      52.18      47.61
#
#             Price_164  Price_165  Price_166  Price_167
# DateTime
# 2016-12-08      36.79      37.94      39.59      42.09
# 2016-12-09      39.01      39.09      40.48      42.41
# 2016-12-10      38.08      39.94      40.29      42.07
# 2016-12-11      30.45      34.25      38.00      40.34
# 2016-12-12      36.34      31.58      32.36      36.14
# ...               ...        ...        ...        ...
# 2020-09-26      32.06      28.73      29.21      29.80
# 2020-09-27      32.54      31.99      32.00      32.17
# 2020-09-28      45.76      36.95      30.03      31.02
# 2020-09-29      38.03      37.06      35.90      35.90
# 2020-09-30      39.85      35.22      32.63      33.70
#
# [1393 rows x 172 columns]

# %% [markdown]
# # Lasso - Garch Model

# %% [markdown]
# ## Dataset Split

# %%
from sklearn.model_selection import train_test_split




# Splitting every dataset for our dependent and independent variables 
X_train = {hour: pd.DataFrame() for hour in hours}
y_train = {hour: pd.DataFrame() for hour in hours}
X_test = {hour: pd.DataFrame() for hour in hours}
y_test = {hour: pd.DataFrame() for hour in hours}



for hour in range(len(hours)):
    X_train[hour], X_test[hour], y_train[hour], y_test[hour] = train_test_split(df_hour[hour].drop(columns='Price'),
                                                                                df_hour[hour]['Price'],
                                                                                test_size=0.20,
                                                                                shuffle=False)

# %% [markdown]
# ## Lasso Regressor and TimeSeriesSplit

# %%
from sklearn.linear_model import LassoCV
from sklearn.model_selection import TimeSeriesSplit
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Creating datasets that will store the models and the prediction prices
y_pred = {hour: pd.DataFrame() for hour in hours}
model_train = {hour: pd.DataFrame() for hour in hours}
y_train_pred = {hour: pd.DataFrame() for hour in hours}

# Lists to fill for the scores
rsquared_test = []
rsquared_train = []
model_name = []
mae = []
rmse = []
alpha = []



for hour in hours:
    # Creating fold strategy
    tscv = TimeSeriesSplit(n_splits=5)
    num_cols = df_hour[hour].drop(columns=['Price']).columns.to_list()
    num_pipeline = Pipeline(steps=[
        ('scale', StandardScaler())
        ])
    trans_pipeline = ColumnTransformer(transformers=[
        ('num_pipeline', num_pipeline, num_cols)
    ], remainder='drop', n_jobs=-1)

    Lasso = LassoCV(cv=tscv, random_state=0)

    lasso_pipeline = Pipeline(steps=[
        ('trans_pipeline', trans_pipeline),
        ('model', Lasso)
    ])

    model_train[hour] = lasso_pipeline.fit(X_train[hour], y_train[hour])
    y_train_pred[hour] = model_train[hour].predict(X_train[hour])
    y_pred[hour]= model_train[hour].predict(X_test[hour])
    train_score = r2_score(y_train[hour], y_train_pred[hour])
    test_score = r2_score(y_test[hour], y_pred[hour])
    mae_score = mean_absolute_error(y_test[hour], y_pred[hour])
    rmse_score = mean_squared_error(y_test[hour], y_pred[hour])
    mae.append(mae_score)
    rmse.append(rmse_score)
    rsquared_test.append(test_score)
    rsquared_train.append(train_score)
    alpha.append(model_train[hour][1].alpha_)

    model_name.append('LASSO-D FOR HOUR_[' + str(hour) + ']')


model_results = pd.DataFrame(columns=['Model', 'Rsquared Value Train', 'Rsquared Value Test', 'Smoothing Parameter'])
model_results['Model'] = model_name
model_results['Rsquared Value Train'] = rsquared_train
model_results['Rsquared Value Test'] = rsquared_test
model_results['MAE Score'] = mae
model_results['RMSE Score'] = rmse
model_results['Smoothing Parameter'] = alpha

# Table that shows the results for every trained model
model_results
# Out:
#                     Model  Rsquared Value Train  Rsquared Value Test  \
# 0    LASSO-D FOR HOUR_[0]              0.902528             0.907310
# 1    LASSO-D FOR HOUR_[1]              0.878640             0.802073
# 2    LASSO-D FOR HOUR_[2]              0.846797             0.739065
# 3    LASSO-D FOR HOUR_[3]              0.817321             0.699778
# 4    LASSO-D FOR HOUR_[4]              0.768156             0.663485
# 5    LASSO-D FOR HOUR_[5]              0.755600             0.589416
# 6    LASSO-D FOR HOUR_[6]              0.782729             0.580479
# 7    LASSO-D FOR HOUR_[7]              0.817802             0.587647
# 8    LASSO-D FOR HOUR_[8]              0.780203             0.653211
# 9    LASSO-D FOR HOUR_[9]              0.759677             0.706777
# 10  LASSO-D FOR HOUR_[10]              0.785453             0.653816
# 11  LASSO-D FOR HOUR_[11]              0.795214             0.553935
# 12  LASSO-D FOR HOUR_[12]              0.818084             0.619563
# 13  LASSO-D FOR HOUR_[13]              0.820787             0.633410
# 14  LASSO-D FOR HOUR_[14]              0.820254             0.626865
# 15  LASSO-D FOR HOUR_[15]              0.755181             0.601579
# 16  LASSO-D FOR HOUR_[16]              0.728317             0.561956
# 17  LASSO-D FOR HOUR_[17]              0.740403             0.478886
# 18  LASSO-D FOR HOUR_[18]              0.688978             0.585203
# 19  LASSO-D FOR HOUR_[19]              0.700573             0.624837
# 20  LASSO-D FOR HOUR_[20]              0.723354             0.491430
# 21  LASSO-D FOR HOUR_[21]              0.812793             0.153819
# 22  LASSO-D FOR HOUR_[22]              0.767986             0.326137
# 23  LASSO-D FOR HOUR_[23]              0.747250             0.404229
#
#     Smoothing Parameter  MAE Score  RMSE Score
# 0              0.089977   1.777142    6.568795
# 1              0.104994   2.714510   15.114373
# 2              0.094307   3.290789   21.313469
# 3              0.100474   3.745250   28.665222
# 4              0.147282   4.457915   39.227317
# 5              0.142177   5.235954   52.025152
# 6              0.141473   6.187444   69.575848
# 7              0.101886   6.076535   59.347244
# 8              0.133469   4.682625   39.187050
# 9              0.193757   4.056812   29.119531
# 10             0.168884   4.091024   32.084618
# 11             0.155658   4.811822   41.270591
# 12             0.168837   4.590364   44.638475
# 13             0.156200   4.592270   48.963673
# 14             0.125604   4.649005   46.244727
# 15             0.169671   4.471157   41.348101
# 16             0.347637   4.917610   63.455299
# 17             0.495667   6.028276  148.715746
# 18             0.493428   5.314876   84.437541
# 19             0.522422   4.057578   31.407664
# 20             0.182970   3.437275   23.168549
# 21             0.137338   4.113305   32.650356
# 22             0.092246   4.378046   35.065457
# 23             0.134855   4.520043   39.808931

# %%
model_results.to_csv(r'C:\Users\2836589S\OneDrive - University of Glasgow\Data\Data Frames\day_ahead_demand_parameters\lasso_demand_parameter.csv')

# %%
model_train[1][1].alpha_
# Out:
# 0.10499436291178234

# %%
mae_score
# Out:
# 4.52004329315789

# %%
model_results['Rsquared Value Train'].mean()
# Out:
# 0.7839200824119635

# %%
model_results['Rsquared Value Test'].mean()
# Out:
# 0.5935377743147688

# %%
model_results['MAE Score'].mean()
# Out:
# 4.424901094441963

# %%
model_results['RMSE Score'].mean()
# Out:
# 44.72515537652203

# %%
# Create multi data frame that will inform us about its coefficients with a descending order

df_coef = {hour: pd.DataFrame() for hour in hours}
for hour in hours:
    df_coef[hour].index = X_train[hour].transpose().index
    df_coef[hour]['Coefficients'] = model_train[hour]['model'].coef_.transpose()
    df_coef[hour].sort_values(by='Coefficients', ascending=False, inplace=True)
    df_coef[hour]

# %%
for hour in hours:
    df_coef[hour]['Hour'] = hour
    df_coef[hour].to_csv(r'C:\Users\2836589S\OneDrive - University of Glasgow\Data\Data Frames\df_coef\df_coef_'+str(hour)+'.csv')

# %%
# Barplot for top 10 coeffiecients (features) for hour 8:00
a = df_coef[12].head(10)
sns.barplot(x=a['Coefficients'],y=a.index )
plt.title('Lasso Regressor Coefficients for 8:00')
plt.ylabel('Features')
plt.xlabel('Coefficients')
# Out:
# Text(0.5, 0, 'Coefficients')

# %%
# Create multi data frame that will provides us with the residuals and squared residuals for every trained model, 
# for every hour


lasso_train = {hour: pd.DataFrame() for hour in hours}
lasso_test = {hour: pd.DataFrame() for hour in hours}

for hour in hours:
    scaler = StandardScaler()
    scaler.fit(X_train[hour])
    lasso_train[hour] = pd.DataFrame(columns=['Actual Value', 'Predicted Value', 'Residual', 'Squared Residuals'])
    lasso_train[hour]['Actual Value'] = y_train[hour]
    lasso_train[hour]['Predicted Value'] = model_train[hour].predict(X_train[hour])
    lasso_train[hour]['Residual'] = lasso_train[hour]['Actual Value'] - lasso_train[hour]['Predicted Value']
    lasso_train[hour]['Squared Residuals'] = lasso_train[hour]['Residual'].mul(lasso_train[hour]['Residual'])

for hour in hours:
    scaler = StandardScaler()
    scaler.fit(X_train[hour])
    lasso_test[hour] = pd.DataFrame(columns=['Actual Value', 'Predicted Value', 'Residual', 'Squared Residuals'])
    lasso_test[hour]['Actual Value'] = y_test[hour]
    lasso_test[hour]['Predicted Value'] = model_train[hour].predict(X_test[hour])
    lasso_test[hour]['Residual'] = lasso_test[hour]['Actual Value'] - lasso_test[hour]['Predicted Value']
    lasso_test[hour]['Squared Residuals'] = lasso_test[hour]['Residual'].mul(lasso_test[hour]['Residual'])


# Example of the table
lasso_train[18]
# Out:
#                      Actual Value  Predicted Value   Residual  \
# DateTime
# 2016-12-08 18:00:00         59.95        68.569611  -8.619611
# 2016-12-09 18:00:00         55.95        64.708171  -8.758171
# 2016-12-10 18:00:00         61.10        65.526347  -4.426347
# 2016-12-11 18:00:00         70.00        70.772195  -0.772195
# 2016-12-12 18:00:00         67.63        69.834821  -2.204821
# ...                           ...              ...        ...
# 2019-12-22 18:00:00         54.53        59.016251  -4.486251
# 2019-12-23 18:00:00         54.54        54.793267  -0.253267
# 2019-12-24 18:00:00         45.60        53.432527  -7.832527
# 2019-12-25 18:00:00         36.70        52.554332 -15.854332
# 2019-12-26 18:00:00         47.42        45.105833   2.314167
#
#                      Squared Residuals
# DateTime
# 2016-12-08 18:00:00          74.297688
# 2016-12-09 18:00:00          76.705554
# 2016-12-10 18:00:00          19.592547
# 2016-12-11 18:00:00           0.596286
# 2016-12-12 18:00:00           4.861237
# ...                                ...
# 2019-12-22 18:00:00          20.126450
# 2019-12-23 18:00:00           0.064144
# 2019-12-24 18:00:00          61.348485
# 2019-12-25 18:00:00         251.359847
# 2019-12-26 18:00:00           5.355367
#
# [1114 rows x 4 columns]

# %%
lasso_test[1]
# Out:
#                      Actual Value  Predicted Value  Residual  \
# DateTime
# 2019-12-27 01:00:00         28.73        32.760600 -4.030600
# 2019-12-28 01:00:00         24.97        29.234499 -4.264499
# 2019-12-29 01:00:00         23.55        24.983093 -1.433093
# 2019-12-30 01:00:00         22.96        22.767276  0.192724
# 2019-12-31 01:00:00         38.00        35.279266  2.720734
# ...                           ...              ...       ...
# 2020-09-26 01:00:00         23.23        25.674851 -2.444851
# 2020-09-27 01:00:00         13.69        20.913881 -7.223881
# 2020-09-28 01:00:00         26.77        25.940262  0.829738
# 2020-09-29 01:00:00         32.54        32.171733  0.368267
# 2020-09-30 01:00:00         35.33        33.794567  1.535433
#
#                      Squared Residuals
# DateTime
# 2019-12-27 01:00:00          16.245735
# 2019-12-28 01:00:00          18.185949
# 2019-12-29 01:00:00           2.053755
# 2019-12-30 01:00:00           0.037142
# 2019-12-31 01:00:00           7.402396
# ...                                ...
# 2020-09-26 01:00:00           5.977295
# 2020-09-27 01:00:00          52.184454
# 2020-09-28 01:00:00           0.688464
# 2020-09-29 01:00:00           0.135620
# 2020-09-30 01:00:00           2.357554
#
# [279 rows x 4 columns]

# %%
sns.lineplot(x=lasso_train[18].index, y=lasso_train[18]['Squared Residuals'])
plt.title('Squared Residuals Timeplot for 18:00')
# Out:
# Text(0.5, 1.0, 'Squared Residuals Timeplot for 18:00')

# %% [markdown]
# ## Garch Model

# %% [markdown]
# ## Working an example

# %%
from arch import arch_model

# Using arch_lasso_exp as an example, variable b takes an int number pointing the hour 
# we want to produce the arch model

b = 5

arch_lasso_exp = arch_model(lasso_train[b]['Residual'], vol='GARCH', p=1,q=1, dist='normal', mean='zero')
arch_lasso_exp = arch_lasso_exp.fit()
arch_lasso_exp.summary()
arch_lasso_exp.forecast(horizon=len(lasso_test[b])).variance.values[-1, :]
# Out:
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 5866.345318798869
# Iteration:      2,   Func. Count:     11,   Neg. LLF: 3420.307328866504
# Iteration:      3,   Func. Count:     17,   Neg. LLF: 3394.800713810755
# Iteration:      4,   Func. Count:     21,   Neg. LLF: 3393.9990993102583
# Iteration:      5,   Func. Count:     25,   Neg. LLF: 3393.7751343393293
# Iteration:      6,   Func. Count:     29,   Neg. LLF: 3393.7224171849007
# Iteration:      7,   Func. Count:     33,   Neg. LLF: 3393.710958034813
# Iteration:      8,   Func. Count:     37,   Neg. LLF: 3393.710184592467
# Iteration:      9,   Func. Count:     41,   Neg. LLF: 3393.7101677884193
# Iteration:     10,   Func. Count:     45,   Neg. LLF: 3393.710166865029
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3393.710166865029
#             Iterations: 10
#             Function evaluations: 45
#             Gradient evaluations: 10
# array([37.26526146, 30.4586459 , 28.61863851, 28.12123606, 27.98677509,
#        27.95042675, 27.94060083, 27.93794463, 27.93722659, 27.93703248,
#        27.93698001, 27.93696583, 27.93696199, 27.93696096, 27.93696067,
#        27.9369606 , 27.93696058, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057, 27.93696057,
#        27.93696057, 27.93696057, 27.93696057, 27.93696057])

# %%
# Producing conditional volatility plot for our garch model

arch_lasso_exp.plot();
plt.title('Volatility for ' + str(b) + ':00')
# Out:
# Text(0.5, 1.0, 'Volatility for 5:00')

# %%
# Plotting the standardized residuals of our garch model

sns.histplot(arch_lasso_exp.std_resid, kde=True)
plt.title('Distribution of Standardized Residuals for GARCH(1,1) - ' + str(b) + ':00')
# Out:
# Text(0.5, 1.0, 'Distribution of Standardized Residuals for GARCH(1,1) - 5:00')

# %%
sm.graphics.tsa.plot_acf(arch_lasso_exp.std_resid);

# %%
# Plotting the qqplot of our standardized residuals

import statsmodels.api as sm
import pylab

x = arch_lasso_exp.std_resid
sm.qqplot(x, line='45')

plt.title('QQplot for Standardized Residuals - GARCH(1,1) ' + str(b) + ':00')
# Out:
# Text(0.5, 1.0, 'QQplot for Standardized Residuals - GARCH(1,1) 5:00')

# %% [markdown]
# ## Training every model

# %%
# Training every garch model for every hour ( takes the residuals from our trained lasso models)

from scipy import stats
garch_lasso_train = {hour: pd.DataFrame() for hour in hours}

for hour in hours:
    garch_lasso_train[hour] = arch_model(lasso_train[hour]['Residual'], vol='GARCH', p=1,q=1, mean='zero').fit()
# Out:
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 3017.3520283828066
# Iteration:      2,   Func. Count:     11,   Neg. LLF: 2868.2704137173414
# Iteration:      3,   Func. Count:     15,   Neg. LLF: 2869.111422554285
# Iteration:      4,   Func. Count:     20,   Neg. LLF: 2994.603763069357
# Iteration:      5,   Func. Count:     26,   Neg. LLF: 2866.886953307399
# Iteration:      6,   Func. Count:     30,   Neg. LLF: 2866.858927806472
# Iteration:      7,   Func. Count:     34,   Neg. LLF: 2866.8552895345565
# Iteration:      8,   Func. Count:     38,   Neg. LLF: 2866.8541001604804
# Iteration:      9,   Func. Count:     42,   Neg. LLF: 2866.8540388043557
# Iteration:     10,   Func. Count:     46,   Neg. LLF: 2866.854034407333
# Iteration:     11,   Func. Count:     49,   Neg. LLF: 2866.8540344073035
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2866.854034407333
#             Iterations: 11
#             Function evaluations: 49
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 3014.618521100514
# Iteration:      2,   Func. Count:     10,   Neg. LLF: 3362.987848934471
# Iteration:      3,   Func. Count:     16,   Neg. LLF: 2965.0298299745014
# Iteration:      4,   Func. Count:     20,   Neg. LLF: 3017.496371374185
# Iteration:      5,   Func. Count:     25,   Neg. LLF: 2964.592925592945
# Iteration:      6,   Func. Count:     29,   Neg. LLF: 2964.5919444097517
# Iteration:      7,   Func. Count:     33,   Neg. LLF: 2964.591872412908
# Iteration:      8,   Func. Count:     36,   Neg. LLF: 2964.5918724132785
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2964.591872412908
#             Iterations: 8
#             Function evaluations: 36
#             Gradient evaluations: 8
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 3141.0200853653214
# Iteration:      2,   Func. Count:     10,   Neg. LLF: 647284287.7899802
# Iteration:      3,   Func. Count:     16,   Neg. LLF: 3029.251079663674
# Iteration:      4,   Func. Count:     21,   Neg. LLF: 3025.126882030889
# Iteration:      5,   Func. Count:     26,   Neg. LLF: 3025.0491848719134
# Iteration:      6,   Func. Count:     30,   Neg. LLF: 3025.049182686461
# Iteration:      7,   Func. Count:     33,   Neg. LLF: 3025.04918268644
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3025.049182686461
#             Iterations: 7
#             Function evaluations: 33
#             Gradient evaluations: 7
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 3168.3655423043115
# Iteration:      2,   Func. Count:     10,   Neg. LLF: 1502145.9773299533
# Iteration:      3,   Func. Count:     16,   Neg. LLF: 3092.346179849622
# Iteration:      4,   Func. Count:     21,   Neg. LLF: 3165.9723410955157
# Iteration:      5,   Func. Count:     26,   Neg. LLF: 3089.851668030485
# Iteration:      6,   Func. Count:     30,   Neg. LLF: 3089.851297760756
# Iteration:      7,   Func. Count:     34,   Neg. LLF: 3089.8512937573423
# Iteration:      8,   Func. Count:     37,   Neg. LLF: 3089.8512937571522
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3089.8512937573423
#             Iterations: 8
#             Function evaluations: 37
#             Gradient evaluations: 8
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 3376.25287297659
# Iteration:      2,   Func. Count:     10,   Neg. LLF: 3387.289391026253
# Iteration:      3,   Func. Count:     16,   Neg. LLF: 3255.2552398281223
# Iteration:      4,   Func. Count:     20,   Neg. LLF: 3340.131669305243
# Iteration:      5,   Func. Count:     25,   Neg. LLF: 3255.4929847191042
# Iteration:      6,   Func. Count:     30,   Neg. LLF: 3253.67188454524
# Iteration:      7,   Func. Count:     34,   Neg. LLF: 3253.660742966121
# Iteration:      8,   Func. Count:     38,   Neg. LLF: 3253.65659102547
# Iteration:      9,   Func. Count:     42,   Neg. LLF: 3253.6555959105085
# Iteration:     10,   Func. Count:     46,   Neg. LLF: 3253.6555803459005
# Iteration:     11,   Func. Count:     50,   Neg. LLF: 3253.655579608207
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3253.655579608207
#             Iterations: 11
#             Function evaluations: 50
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 5866.345318798869
# Iteration:      2,   Func. Count:     11,   Neg. LLF: 3420.307328866504
# Iteration:      3,   Func. Count:     17,   Neg. LLF: 3394.800713810755
# Iteration:      4,   Func. Count:     21,   Neg. LLF: 3393.9990993102583
# Iteration:      5,   Func. Count:     25,   Neg. LLF: 3393.7751343393293
# Iteration:      6,   Func. Count:     29,   Neg. LLF: 3393.7224171849007
# Iteration:      7,   Func. Count:     33,   Neg. LLF: 3393.710958034813
# Iteration:      8,   Func. Count:     37,   Neg. LLF: 3393.710184592467
# Iteration:      9,   Func. Count:     41,   Neg. LLF: 3393.7101677884193
# Iteration:     10,   Func. Count:     45,   Neg. LLF: 3393.710166865029
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3393.710166865029
#             Iterations: 10
#             Function evaluations: 45
#             Gradient evaluations: 10
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 4782.134639161013
# Iteration:      2,   Func. Count:     11,   Neg. LLF: 3463.0423977758255
# Iteration:      3,   Func. Count:     17,   Neg. LLF: 3447.676188677366
# Iteration:      4,   Func. Count:     23,   Neg. LLF: 3429.000749747145
# Iteration:      5,   Func. Count:     27,   Neg. LLF: 3428.9996709853867
# Iteration:      6,   Func. Count:     31,   Neg. LLF: 3428.999669676753
# Iteration:      7,   Func. Count:     34,   Neg. LLF: 3428.999669676704
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3428.999669676753
#             Iterations: 7
#             Function evaluations: 34
#             Gradient evaluations: 7
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 5102.015937640244
# Iteration:      2,   Func. Count:     11,   Neg. LLF: 3478.4025519218917
# Iteration:      3,   Func. Count:     17,   Neg. LLF: 3471.5243870717586
# Iteration:      4,   Func. Count:     23,   Neg. LLF: 3437.4559615753624
# Iteration:      5,   Func. Count:     27,   Neg. LLF: 3437.4541609319385
# Iteration:      6,   Func. Count:     31,   Neg. LLF: 3437.454135233477
# Iteration:      7,   Func. Count:     34,   Neg. LLF: 3437.4541352340157
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3437.454135233477
#             Iterations: 7
#             Function evaluations: 34
#             Gradient evaluations: 7
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 8843.414690107602
# Iteration:      2,   Func. Count:     12,   Neg. LLF: 3751.068928362662
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 3486.127737252044
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 3485.7053646886993
# Iteration:      5,   Func. Count:     28,   Neg. LLF: 3485.703860695438
# Iteration:      6,   Func. Count:     32,   Neg. LLF: 3485.7038486769916
# Iteration:      7,   Func. Count:     35,   Neg. LLF: 3485.7038486769293
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3485.7038486769916
#             Iterations: 7
#             Function evaluations: 35
#             Gradient evaluations: 7
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 17205.43685810145
# Iteration:      2,   Func. Count:     12,   Neg. LLF: 3862.6586538192614
# Iteration:      3,   Func. Count:     18,   Neg. LLF: 3435.6532561921167
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 3429.867842519155
# Iteration:      5,   Func. Count:     28,   Neg. LLF: 3429.8676795309802
# Iteration:      6,   Func. Count:     32,   Neg. LLF: 3429.867678124136
# Iteration:      7,   Func. Count:     35,   Neg. LLF: 3429.8676781245267
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3429.867678124136
#             Iterations: 7
#             Function evaluations: 35
#             Gradient evaluations: 7
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 3545.244512619606
# Iteration:      2,   Func. Count:     11,   Neg. LLF: 3380.5761310721055
# Iteration:      3,   Func. Count:     16,   Neg. LLF: 3331.645563967958
# Iteration:      4,   Func. Count:     20,   Neg. LLF: 3331.641679270455
# Iteration:      5,   Func. Count:     24,   Neg. LLF: 3331.637615568142
# Iteration:      6,   Func. Count:     28,   Neg. LLF: 3331.635469832321
# Iteration:      7,   Func. Count:     32,   Neg. LLF: 3331.634357436368
# Iteration:      8,   Func. Count:     36,   Neg. LLF: 3331.6342914805687
# Iteration:      9,   Func. Count:     39,   Neg. LLF: 3331.634291480146
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3331.6342914805687
#             Iterations: 9
#             Function evaluations: 39
#             Gradient evaluations: 9
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 3335.375430333496
# Iteration:      2,   Func. Count:     11,   Neg. LLF: 3654.330350681702
# Iteration:      3,   Func. Count:     16,   Neg. LLF: 3281.9923647657824
# Iteration:      4,   Func. Count:     21,   Neg. LLF: 3281.52254187226
# Iteration:      5,   Func. Count:     26,   Neg. LLF: 3280.082777351854
# Iteration:      6,   Func. Count:     30,   Neg. LLF: 3280.081858067774
# Iteration:      7,   Func. Count:     34,   Neg. LLF: 3280.081856586087
# Iteration:      8,   Func. Count:     37,   Neg. LLF: 3280.081856586009
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3280.081856586087
#             Iterations: 8
#             Function evaluations: 37
#             Gradient evaluations: 8
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 5742.893238182556
# Iteration:      2,   Func. Count:     11,   Neg. LLF: 3303.606542475646
# Iteration:      3,   Func. Count:     17,   Neg. LLF: 3266.514349640417
# Iteration:      4,   Func. Count:     21,   Neg. LLF: 3264.8937762505693
# Iteration:      5,   Func. Count:     25,   Neg. LLF: 3264.6478220519216
# Iteration:      6,   Func. Count:     29,   Neg. LLF: 3264.4987607487637
# Iteration:      7,   Func. Count:     33,   Neg. LLF: 3264.4928245150722
# Iteration:      8,   Func. Count:     37,   Neg. LLF: 3264.491451339809
# Iteration:      9,   Func. Count:     41,   Neg. LLF: 3264.4914084716647
# Iteration:     10,   Func. Count:     45,   Neg. LLF: 3264.4914074109543
# Iteration:     11,   Func. Count:     48,   Neg. LLF: 3264.4914075185234
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3264.4914074109543
#             Iterations: 11
#             Function evaluations: 48
#             Gradient evaluations: 11
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 3431.8166407335607
# Iteration:      2,   Func. Count:     11,   Neg. LLF: 3816.150161452111
# Iteration:      3,   Func. Count:     18,   Neg. LLF: 3245.3900779993155
# Iteration:      4,   Func. Count:     23,   Neg. LLF: 3251.77676482607
# Iteration:      5,   Func. Count:     28,   Neg. LLF: 3244.1068126120367
# Iteration:      6,   Func. Count:     32,   Neg. LLF: 3244.1009434565162
# Iteration:      7,   Func. Count:     36,   Neg. LLF: 3244.10004073409
# Iteration:      8,   Func. Count:     40,   Neg. LLF: 3244.09878204469
# Iteration:      9,   Func. Count:     44,   Neg. LLF: 3244.098772754407
# Iteration:     10,   Func. Count:     47,   Neg. LLF: 3244.0987727536176
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3244.098772754407
#             Iterations: 10
#             Function evaluations: 47
#             Gradient evaluations: 10
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 233470.00137894895
# Iteration:      2,   Func. Count:     11,   Neg. LLF: 3315.2386274280943
# Iteration:      3,   Func. Count:     18,   Neg. LLF: 3244.593829080222
# Iteration:      4,   Func. Count:     25,   Neg. LLF: 3242.7112919528995
# Iteration:      5,   Func. Count:     29,   Neg. LLF: 3242.7017408307165
# Iteration:      6,   Func. Count:     33,   Neg. LLF: 3242.7008812781887
# Iteration:      7,   Func. Count:     37,   Neg. LLF: 3242.7008653110934
# Iteration:      8,   Func. Count:     41,   Neg. LLF: 3242.700864372303
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3242.700864372303
#             Iterations: 8
#             Function evaluations: 41
#             Gradient evaluations: 8
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 5877.736914589684
# Iteration:      2,   Func. Count:     12,   Neg. LLF: 3790.8868803687756
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 3454.513012536704
# Iteration:      4,   Func. Count:     25,   Neg. LLF: 3451.2408406326144
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 3451.2406476582983
# Iteration:      6,   Func. Count:     33,   Neg. LLF: 3451.240647658442
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3451.2406476582983
#             Iterations: 6
#             Function evaluations: 33
#             Gradient evaluations: 6
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 5521.836738657838
# Iteration:      2,   Func. Count:     11,   Neg. LLF: 3789.087675121894
# Iteration:      3,   Func. Count:     16,   Neg. LLF: 4184.521543414434
# Iteration:      4,   Func. Count:     21,   Neg. LLF: 3792.392031517988
# Iteration:      5,   Func. Count:     26,   Neg. LLF: 3776.952644944009
# Iteration:      6,   Func. Count:     30,   Neg. LLF: 3776.9496070835435
# Iteration:      7,   Func. Count:     34,   Neg. LLF: 3776.949589958147
# Iteration:      8,   Func. Count:     38,   Neg. LLF: 3776.9495895228724
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3776.9495895228724
#             Iterations: 8
#             Function evaluations: 38
#             Gradient evaluations: 8
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 4946.698087267537
# Iteration:      2,   Func. Count:     11,   Neg. LLF: 3917.281234197383
# Iteration:      3,   Func. Count:     16,   Neg. LLF: 3950.5631540224867
# Iteration:      4,   Func. Count:     21,   Neg. LLF: 3912.0220099168528
# Iteration:      5,   Func. Count:     26,   Neg. LLF: 3910.4575779285187
# Iteration:      6,   Func. Count:     30,   Neg. LLF: 3910.440609635156
# Iteration:      7,   Func. Count:     34,   Neg. LLF: 3910.440253295532
# Iteration:      8,   Func. Count:     38,   Neg. LLF: 3910.4402334661645
# Iteration:      9,   Func. Count:     42,   Neg. LLF: 3910.4402329275013
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3910.4402329275013
#             Iterations: 9
#             Function evaluations: 42
#             Gradient evaluations: 9
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 5687.937202533136
# Iteration:      2,   Func. Count:     10,   Neg. LLF: 3958.468168961125
# Iteration:      3,   Func. Count:     15,   Neg. LLF: 3901.782615831984
# Iteration:      4,   Func. Count:     20,   Neg. LLF: 4089.70853160111
# Iteration:      5,   Func. Count:     25,   Neg. LLF: 3900.9505118794523
# Iteration:      6,   Func. Count:     30,   Neg. LLF: 3900.1151603577127
# Iteration:      7,   Func. Count:     35,   Neg. LLF: 3900.030017670184
# Iteration:      8,   Func. Count:     39,   Neg. LLF: 3900.0300150721573
# Iteration:      9,   Func. Count:     42,   Neg. LLF: 3900.0300150727144
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3900.0300150721573
#             Iterations: 9
#             Function evaluations: 42
#             Gradient evaluations: 9
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 4899.305954924067
# Iteration:      2,   Func. Count:     11,   Neg. LLF: 3721.9594513544016
# Iteration:      3,   Func. Count:     17,   Neg. LLF: 386615.41670902824
# Iteration:      4,   Func. Count:     22,   Neg. LLF: 3691.9952333434944
# Iteration:      5,   Func. Count:     27,   Neg. LLF: 3691.2701858897417
# Iteration:      6,   Func. Count:     31,   Neg. LLF: 3691.2672022939246
# Iteration:      7,   Func. Count:     35,   Neg. LLF: 3691.2671694048863
# Iteration:      8,   Func. Count:     39,   Neg. LLF: 3691.267163856245
# Iteration:      9,   Func. Count:     42,   Neg. LLF: 3691.2671638562533
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3691.267163856245
#             Iterations: 9
#             Function evaluations: 42
#             Gradient evaluations: 9
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 100208.46031196805
# Iteration:      2,   Func. Count:     11,   Neg. LLF: 3410.029971964287
# Iteration:      3,   Func. Count:     18,   Neg. LLF: 3369.7433396510023
# Iteration:      4,   Func. Count:     23,   Neg. LLF: 3425.14398649787
# Iteration:      5,   Func. Count:     28,   Neg. LLF: 3367.3592315345413
# Iteration:      6,   Func. Count:     33,   Neg. LLF: 3367.325585754516
# Iteration:      7,   Func. Count:     37,   Neg. LLF: 3367.324218910696
# Iteration:      8,   Func. Count:     40,   Neg. LLF: 3367.3242189080643
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3367.324218910696
#             Iterations: 8
#             Function evaluations: 40
#             Gradient evaluations: 8
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 6235.3663728873335
# Iteration:      2,   Func. Count:     12,   Neg. LLF: 3163.7586204847576
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 3392.6433021878893
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 3140.301924972518
# Iteration:      5,   Func. Count:     29,   Neg. LLF: 3133.847133577322
# Iteration:      6,   Func. Count:     34,   Neg. LLF: 3120.700438494502
# Iteration:      7,   Func. Count:     39,   Neg. LLF: 3119.3251536239704
# Iteration:      8,   Func. Count:     44,   Neg. LLF: 3119.255796993196
# Iteration:      9,   Func. Count:     48,   Neg. LLF: 3119.254083832416
# Iteration:     10,   Func. Count:     52,   Neg. LLF: 3119.2540538546605
# Iteration:     11,   Func. Count:     56,   Neg. LLF: 3119.2540508621746
# Iteration:     12,   Func. Count:     60,   Neg. LLF: 3119.2540502950706
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3119.2540502950706
#             Iterations: 12
#             Function evaluations: 60
#             Gradient evaluations: 12
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 6146.8053156485985
# Iteration:      2,   Func. Count:     12,   Neg. LLF: 3372.248212002441
# Iteration:      3,   Func. Count:     19,   Neg. LLF: 71782.84540143108
# Iteration:      4,   Func. Count:     24,   Neg. LLF: 3263.9203187887506
# Iteration:      5,   Func. Count:     28,   Neg. LLF: 3263.882844723694
# Iteration:      6,   Func. Count:     32,   Neg. LLF: 3263.9579008695464
# Iteration:      7,   Func. Count:     37,   Neg. LLF: 3263.8601937638095
# Iteration:      8,   Func. Count:     41,   Neg. LLF: 3263.860174850016
# Iteration:      9,   Func. Count:     44,   Neg. LLF: 3263.860174850423
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3263.860174850016
#             Iterations: 9
#             Function evaluations: 44
#             Gradient evaluations: 9
# Iteration:      1,   Func. Count:      5,   Neg. LLF: 3381.6959103115223
# Iteration:      2,   Func. Count:     11,   Neg. LLF: 3433.271560532995
# Iteration:      3,   Func. Count:     16,   Neg. LLF: 3363.970367374876
# Iteration:      4,   Func. Count:     22,   Neg. LLF: 3340.475952232059
# Iteration:      5,   Func. Count:     26,   Neg. LLF: 3340.4755504099944
# Iteration:      6,   Func. Count:     30,   Neg. LLF: 3340.4755195397966
# Iteration:      7,   Func. Count:     33,   Neg. LLF: 3340.47551953978
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 3340.4755195397966
#             Iterations: 7
#             Function evaluations: 33
#             Gradient evaluations: 7

# %%
fig = garch_lasso_train[2].plot()

# %%
garch_lasso_results = {hour: pd.DataFrame() for hour in hours}

for hour in hours:
    garch_lasso_results[hour]['Actual Value'] = lasso_test[hour]['Actual Value']
    garch_lasso_results[hour]['Predicted Value'] = lasso_test[hour]['Predicted Value']
    garch_lasso_results[hour]['Residual'] = lasso_test[hour]['Residual']
    garch_lasso_results[hour]['Squared Residuals'] = lasso_test[hour]['Squared Residuals']
    garch_lasso_results[hour]['STD'] = np.sqrt(garch_lasso_train[hour].forecast(horizon=len(lasso_test[hour])).variance.values[-1, :])

# %%
garch_lasso_results[5].to_csv(r'C:\Users\2836589S\OneDrive - University of Glasgow\Data\Data Frames\garch_lasso_results_5.csv')

# %% [markdown]
# # Lasso with constant standard deviation

# %%
# Residual and STD functions need attention

lasso_mean_results = {hour: pd.DataFrame() for hour in hours}
for hour in hours:
    lasso_mean_results[hour]['Actual Value'] = lasso_test[hour]['Actual Value']
    lasso_mean_results[hour]['Predicted Value'] = lasso_test[hour]['Predicted Value']
    lasso_mean_results[hour]['Error'] = lasso_test[hour]['Actual Value'] - lasso_test[hour]['Predicted Value']
    lasso_mean_results[hour]['Squared Errors'] = lasso_test[hour]['Squared Residuals']
    lasso_mean_results[hour]['STD'] = lasso_train[hour]['Residual'].std()

# %%
lasso_mean_results[4]
# Out:
#                      Actual Value  Predicted Value      Error  Squared Errors  \
# DateTime
# 2019-12-27 04:00:00         24.70        22.440192   2.259808        5.106733
# 2019-12-28 04:00:00         19.04        22.335725  -3.295725       10.861804
# 2019-12-29 04:00:00         17.79        18.648364  -0.858364        0.736789
# 2019-12-30 04:00:00         19.92        18.731467   1.188533        1.412611
# 2019-12-31 04:00:00         28.93        27.678201   1.251799        1.567002
# ...                           ...              ...        ...             ...
# 2020-09-26 04:00:00         25.82        27.975046  -2.155046        4.644224
# 2020-09-27 04:00:00         16.83        28.717369 -11.887369      141.309537
# 2020-09-28 04:00:00         42.00        33.579271   8.420729       70.908668
# 2020-09-29 04:00:00         45.71        40.128883   5.581117       31.148872
# 2020-09-30 04:00:00         44.02        38.742317   5.277683       27.853935
#
#                           STD
# DateTime
# 2019-12-27 04:00:00  4.690681
# 2019-12-28 04:00:00  4.690681
# 2019-12-29 04:00:00  4.690681
# 2019-12-30 04:00:00  4.690681
# 2019-12-31 04:00:00  4.690681
# ...                       ...
# 2020-09-26 04:00:00  4.690681
# 2020-09-27 04:00:00  4.690681
# 2020-09-28 04:00:00  4.690681
# 2020-09-29 04:00:00  4.690681
# 2020-09-30 04:00:00  4.690681
#
# [279 rows x 5 columns]

# %% [markdown]
# # Lasso - ARIMA Model

# %% [markdown]
# ## Trainning ARIMA and Parameter Estimation

# %%
import statsmodels.api as sm
import pmdarima as pm

# %%
arima_train = {hour: pd.DataFrame() for hour in hours}
arima_order = {hour: pd.DataFrame() for hour in hours}

arima_hour = []
arima_pqd = []

for hour in hours:
    arima_train[hour] = pm.auto_arima(lasso_train[hour]['Residual'],
                                      test='adf',
                                      suppress_warnings=True,
                                      stepwise=True,
                                      trace=False,
                                      information_criterion='aic')
    arima_hour.append('ARMA-D on HOUR_ '+ str(hour))
    arima_pqd.append(arima_train[hour].order)

# %%
arima_order_df = pd.DataFrame(columns=['Arima Model', 'Arima Order'])
arima_order_df['Arima Model'] = arima_hour
arima_order_df['Arima Order'] = arima_pqd
arima_order_df
# Out:
#            Arima Model Arima Order
# 0    ARMA-D on HOUR_ 0   (1, 0, 1)
# 1    ARMA-D on HOUR_ 1   (1, 0, 1)
# 2    ARMA-D on HOUR_ 2   (1, 0, 2)
# 3    ARMA-D on HOUR_ 3   (2, 0, 1)
# 4    ARMA-D on HOUR_ 4   (1, 0, 1)
# 5    ARMA-D on HOUR_ 5   (1, 0, 1)
# 6    ARMA-D on HOUR_ 6   (2, 0, 2)
# 7    ARMA-D on HOUR_ 7   (1, 0, 1)
# 8    ARMA-D on HOUR_ 8   (2, 0, 1)
# 9    ARMA-D on HOUR_ 9   (1, 0, 1)
# 10  ARMA-D on HOUR_ 10   (1, 0, 2)
# 11  ARMA-D on HOUR_ 11   (1, 0, 1)
# 12  ARMA-D on HOUR_ 12   (1, 0, 0)
# 13  ARMA-D on HOUR_ 13   (1, 0, 1)
# 14  ARMA-D on HOUR_ 14   (1, 0, 1)
# 15  ARMA-D on HOUR_ 15   (1, 0, 2)
# 16  ARMA-D on HOUR_ 16   (1, 0, 1)
# 17  ARMA-D on HOUR_ 17   (1, 0, 1)
# 18  ARMA-D on HOUR_ 18   (1, 0, 1)
# 19  ARMA-D on HOUR_ 19   (1, 0, 1)
# 20  ARMA-D on HOUR_ 20   (2, 0, 2)
# 21  ARMA-D on HOUR_ 21   (3, 0, 2)
# 22  ARMA-D on HOUR_ 22   (1, 0, 1)
# 23  ARMA-D on HOUR_ 23   (2, 0, 2)

# %%
arima_order_df.to_csv(r'C:\Users\2836589S\OneDrive - University of Glasgow\Data\Data Frames\day_ahead_demand_parameters\ARMA-D_parameters.csv')

# %%
lasso_arima_results = {hour: pd.DataFrame() for hour in hours}
arima_forecast = {hour: pd.DataFrame() for hour in hours}
mae_arima = []
rmse_arima = []
model_name = []

for hour in hours:
    arima_forecast[hour] = arima_train[hour].predict(n_periods=len(lasso_test[hour]))

for hour in hours:
    lasso_arima_results[hour]['Actual Value'] = lasso_test[hour]['Actual Value']
    lasso_arima_results[hour]['Predicted Mean Value'] = lasso_test[hour]['Predicted Value']
    lasso_arima_results[hour]['Predicted Residual'] = arima_forecast[hour]
    lasso_arima_results[hour]['Predicted Value'] = lasso_arima_results[hour]['Predicted Mean Value'] + lasso_arima_results[hour]['Predicted Residual']
    lasso_arima_results[hour]['Error'] = lasso_arima_results[hour]['Actual Value'] - lasso_arima_results[hour]['Predicted Value']
    lasso_arima_results[hour]['STD'] = (lasso_train[hour]['Residual']-arima_train[hour].predict_in_sample()).std()
    mae = mean_absolute_error(lasso_arima_results[hour]['Actual Value'], lasso_arima_results[hour]['Predicted Value'])
    rmse = mean_squared_error(lasso_arima_results[hour]['Actual Value'], lasso_arima_results[hour]['Predicted Value'])
    mae_arima.append(mae)
    rmse_arima.append(rmse)
    model_name.append('lasso_arima_model[' + str(hour) + ']')
    
lasso_arima_scores = pd.DataFrame(columns=['Model', 'MAE', 'RMSE'])
lasso_arima_scores['Model'] = model_name
lasso_arima_scores['MAE'] = mae_arima
lasso_arima_scores['RMSE'] = rmse_arima

# %%
lasso_arima_scores['MAE'].mean()
# Out:
# 4.333104529730932

# %%
lasso_arima_scores['RMSE'].mean()
# Out:
# 44.435719161239426

# %% [markdown]
# # Evaluation Metrics

# %% [markdown]
# ## Reliability Diagrams

# %%
from ProbEval import reliability_diagram

# %%
# %%capture

# h = 5

# reliability_diagram(lasso_arima_results[h],obs='Actual Value',mu='Predicted Value',std='STD',plot=True,c='red',l='LASSO-ARMA_'+str(h),m='o')
# reliability_diagram(lasso_mean_results[h],obs='Actual Value',mu='Predicted Value',std='STD',plot=True,c='green',l='LASSO-BENACHMARK_'+str(h),m='o')
# reliability_diagram(garch_lasso_results[h],obs='Actual Value',mu='Predicted Value',std='STD',plot=True,c='blue',l='LASSO-GARCH_'+str(h),m='s')

    
fig = {hour: pd.DataFrame() for hour in hours}    

for h in hours:
    fig[h] = plt.figure()
    reliability_diagram(lasso_arima_results[h],obs='Actual Value',mu='Predicted Value',std='STD',plot=True,c='red',l='LASSO-ARMA_'+str(h),m='o')
    reliability_diagram(lasso_mean_results[h],obs='Actual Value',mu='Predicted Value',std='STD',plot=True,c='green',l='LASSO-BENACHMARK_'+str(h),m='o')
    reliability_diagram(garch_lasso_results[h],obs='Actual Value',mu='Predicted Value',std='STD',plot=True,c='blue',l='LASSO-GARCH_'+str(h),m='s')
   

    
    
for h in hours:    
    fig[h].savefig(r'C:\Users\2836589S\OneDrive - University of Glasgow\Data\Data Frames\day_ahead_reliability\Reliability Diagram_without_demand_' +str(h)+'.png')

# %% [markdown]
# ## CRPS

# %%
from ProbEval import crps_norm

# %%
crps_score_table = pd.DataFrame(columns=('Model', 'LASSO-GARCH CRPS', 'LASSO Benchmark CRPS', 'LASSO-ARIMA CRPS'))
lasso_garch_crps = {hour: pd.DataFrame() for hour in hours}
lasso_mean_crps = {hour: pd.DataFrame() for hour in hours}
lasso_arima_crps = {hour: pd.DataFrame() for hour in hours}

l_g_crps = []
l_m_crps = []
l_a_crps = []
h = []


for hour in hours:
    lasso_garch_crps[hour] = crps_norm(garch_lasso_results[hour],
                                 obs='Actual Value',
                                 m='Predicted Value',
                                 sigma='STD')
    l_g_crps.append(np.mean(lasso_garch_crps[hour]))

    lasso_mean_crps[hour] = crps_norm(lasso_mean_results[hour],
                                      obs='Actual Value',
                                      m='Predicted Value',
                                      sigma='STD')
    l_m_crps.append(np.mean(lasso_mean_crps[hour]))

    lasso_arima_crps[hour] = crps_norm(lasso_arima_results[hour],
                                       obs='Actual Value',
                                       m='Predicted Value',
                                       sigma='STD')
    l_a_crps.append(np.mean(lasso_arima_crps[hour]))

    h.append('Model at time: '+ str(hour))


crps_score_table['Model'] = h
crps_score_table['LASSO-GARCH CRPS'] = l_g_crps
crps_score_table['LASSO Benchmark CRPS'] = l_m_crps
crps_score_table['LASSO-ARIMA CRPS'] = l_a_crps

# %%
crps_score_table
# Out:
#                 Model  LASSO-GARCH CRPS  LASSO Benchmark CRPS  \
# 0    Model at time: 0          1.400620              1.399618
# 1    Model at time: 1          2.098220              2.092809
# 2    Model at time: 2          2.508536              2.508207
# 3    Model at time: 3          2.891100              2.891422
# 4    Model at time: 4          3.426413              3.419133
# 5    Model at time: 5          3.922122              3.925262
# 6    Model at time: 6          4.635189              4.640152
# 7    Model at time: 7          4.394121              4.395443
# 8    Model at time: 8          3.326212              3.328945
# 9    Model at time: 9          2.926438              2.931027
# 10  Model at time: 10          3.005398              3.006599
# 11  Model at time: 11          3.476799              3.475383
# 12  Model at time: 12          3.444760              3.445716
# 13  Model at time: 13          3.452413              3.451391
# 14  Model at time: 14          3.459043              3.457817
# 15  Model at time: 15          3.398010              3.416409
# 16  Model at time: 16          3.892509              3.872877
# 17  Model at time: 17          5.205848              4.830398
# 18  Model at time: 18          4.618224              4.320087
# 19  Model at time: 19          3.121656              3.101064
# 20  Model at time: 20          2.578973              2.580662
# 21  Model at time: 21          3.021026              3.021912
# 22  Model at time: 22          3.215549              3.223285
# 23  Model at time: 23          3.572334              3.575019
#
#     LASSO-ARIMA CRPS
# 0           1.396567
# 1           2.087974
# 2           2.501709
# 3           2.891007
# 4           3.437039
# 5           3.929871
# 6           4.651243
# 7           4.402129
# 8           3.327909
# 9           2.931795
# 10          3.015341
# 11          3.482912
# 12          3.445711
# 13          3.420181
# 14          3.437747
# 15          3.415057
# 16          3.864330
# 17          4.828179
# 18          4.309970
# 19          3.096459
# 20          2.580662
# 21          3.026371
# 22          3.224558
# 23          3.581858

# %%
crps_score_table['LASSO-GARCH CRPS'].mean()
# Out:
# 3.374646326684387

# %%
crps_score_table['LASSO Benchmark CRPS'].mean()
# Out:
# 3.346276526414956

# %%
crps_score_table['LASSO-ARIMA CRPS'].mean()
# Out:
# 3.345274112697464

# %% [markdown]
# ## Pinball Loss

# %%
from ProbEval import pinball_loss_norm

# %%
# %%capture

# fig = {hour: pd.DataFrame() for hour in hours}


# for h in hours:
#     %load_ext autoreload

#     %autoreload 2


#     pinball_loss_norm(lasso_arima_results[h],
#                       obs='Actual Value',
#                       mu='Predicted Value',
#                       std='STD',
#                       l='Lasso-ARIMA' + str(h),
#                       c='blue')
#     pinball_loss_norm(garch_lasso_results[h],
#                       obs='Actual Value',
#                       mu='Predicted Value',
#                       std='STD',
#                       l='GARCH-Lasso' + str(h),
#                       c='red')
#     pinball_loss_norm(lasso_mean_results[h],
#                       obs='Actual Value',
#                       mu='Predicted Value',
#                       std='STD',
#                       l='Lasso Constant Std' + str(h),
#                       c='green')
#     fig[h] = plt.figure()

# for h in hours:
#     fig[h].savefig(r'C:\Users\2836589S\OneDrive - University of Glasgow\VScode Projects\Price Timeseries UK\Plots\Pinball Loss Diagrams\Pinball Loss_'+str(h)+'.png')

# %%
h = 2

# %%
lasso_test[2]
# Out:
#                      Actual Value  Predicted Value   Residual  \
# DateTime
# 2019-12-27 02:00:00         24.99        29.481335  -4.491335
# 2019-12-28 02:00:00         23.09        24.936940  -1.846940
# 2019-12-29 02:00:00         19.99        22.518173  -2.528173
# 2019-12-30 02:00:00         19.81        20.749638  -0.939638
# 2019-12-31 02:00:00         31.05        31.560433  -0.510433
# ...                           ...              ...        ...
# 2020-09-26 02:00:00         20.57        24.742589  -4.172589
# 2020-09-27 02:00:00         11.31        22.844003 -11.534003
# 2020-09-28 02:00:00         26.88        25.227233   1.652767
# 2020-09-29 02:00:00         34.12        31.670069   2.449931
# 2020-09-30 02:00:00         35.09        33.151991   1.938009
#
#                      Squared Residuals
# DateTime
# 2019-12-27 02:00:00          20.172090
# 2019-12-28 02:00:00           3.411187
# 2019-12-29 02:00:00           6.391657
# 2019-12-30 02:00:00           0.882920
# 2019-12-31 02:00:00           0.260542
# ...                                ...
# 2020-09-26 02:00:00          17.410498
# 2020-09-27 02:00:00         133.033227
# 2020-09-28 02:00:00           2.731640
# 2020-09-29 02:00:00           6.002161
# 2020-09-30 02:00:00           3.755880
#
# [279 rows x 4 columns]

# %%
sns.lineplot(x=lasso_test[h].index, y=lasso_test[h]['Actual Value'])
sns.lineplot(x=lasso_test[h].index, y=lasso_test[h]['Predicted Value'])
# Out:
# <AxesSubplot:xlabel='DateTime', ylabel='Actual Value'>

# %%
crps_lasso_garch = crps_norm(garch_lasso_results[h],obs='Actual Value',m='Predicted Value',sigma='STD')

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# %%
param={'n_estimators':[100,300,500]}

# %%
# Create empty dataframes with hour as index in order to fill the trained models, and train them accordingly
model_rf = {hour: pd.DataFrame() for hour in hours}
train_pred = {hour: pd.DataFrame() for hour in hours}
test_pred = {hour: pd.DataFrame() for hour in hours}




# We will traing every model for every hour, and we generate a data frame that will inform us about the r-squared,
# alpha value and intercept for every model

rsquared_test_rf = []
rsquared_train_rf = []
model_name_rf = []
random_pred = []


# grid = GridSearchCV(RandomForestRegressor(), param_grid=param, cv=tscv, n_jobs=-1)

regressor = RandomForestRegressor(n_estimators=300)

for hour in hours:
    model_rf[hour] = regressor.fit(X_train[hour], y_train[hour])
    train_pred[hour] = model_rf[hour].predict(X_train[hour])
    test_pred[hour] = model_rf[hour].predict(X_test[hour])
    train_score = r2_score(y_train[hour], train_pred[hour])
    test_score = r2_score(y_test[hour], test_pred[hour])

    rsquared_train_rf.append(train_score)
    rsquared_test_rf.append(test_score)

    model_name_rf.append('rf_model[' + str(hour) + ']')

model_results_rf = pd.DataFrame(columns=['Model', 'Rsquared Value Train', 'Rsquared Value Test'])
model_results_rf['Model'] = model_name_rf
model_results_rf['Rsquared Value Train'] = rsquared_train_rf
model_results_rf['Rsquared Value Test'] = rsquared_test_rf



# Table that shows the results for every trained model
model_results_rf
# Out:
#            Model  Rsquared Value Train  Rsquared Value Test
# 0    rf_model[0]              0.983007             0.615577
# 1    rf_model[1]              0.980156             0.547392
# 2    rf_model[2]              0.975099             0.483523
# 3    rf_model[3]              0.970484             0.463573
# 4    rf_model[4]              0.965263             0.424186
# 5    rf_model[5]              0.964534             0.372915
# 6    rf_model[6]              0.956954             0.276880
# 7    rf_model[7]              0.952183             0.130047
# 8    rf_model[8]              0.950886            -0.111667
# 9    rf_model[9]              0.958051             0.006944
# 10  rf_model[10]              0.962080             0.123780
# 11  rf_model[11]              0.964240             0.125825
# 12  rf_model[12]              0.968133             0.071130
# 13  rf_model[13]              0.969472             0.161172
# 14  rf_model[14]              0.969434             0.094086
# 15  rf_model[15]              0.956830            -0.341163
# 16  rf_model[16]              0.954963            -0.137636
# 17  rf_model[17]              0.960486             0.215576
# 18  rf_model[18]              0.953363            -0.209301
# 19  rf_model[19]              0.958556             0.195887
# 20  rf_model[20]              0.959305             0.311582
# 21  rf_model[21]              0.970810             0.236405
# 22  rf_model[22]              0.962560            -0.292426
# 23  rf_model[23]              0.961357             0.132352

# %%
model_results_rf['Rsquared Value Train'].mean()
# Out:
# 0.9636751755993855

# %%
model_results_rf['Rsquared Value Test'].mean()
# Out:
# 0.16236005402673434

# %%
h = 5

inspection_df = pd.DataFrame()
inspection_df['Actual'] = y_test[h]
inspection_df['Predicted'] = test_pred[h]
sns.lineplot(x=inspection_df.index, y=inspection_df['Actual'])
sns.lineplot(x=inspection_df.index, y=inspection_df['Predicted'])
# Out:
# <AxesSubplot:xlabel='DateTime', ylabel='Actual'>

# %% [markdown]
# # Lasso with dummy variables

# %% [markdown]
# ## Creating dummy variables

# %%
df_model_dummies = df_model[['Price', 'Solar Generation', 'Wind OffGeneration', 'Wind OnGeneration']]

# %%
df_model_dummies['Month'] = df_model_dummies.index.month
df_model_dummies['Day'] = df_model_dummies.index.dayofweek
df_model_dummies['Week'] = df_model_dummies.index.weekofyear
df_model_dummies['Day_of_Week'] = df_model_dummies.index.dayofweek
df_model_dummies['Hour'] = df_model.index.hour
df_model_dummies
# Out:
#                      Price  Solar Generation  Wind OffGeneration  \
# DateTime
# 2016-12-07 23:00:00  37.92               0.0            7.709530
# 2016-12-08 00:00:00  37.76               0.0            7.517084
# 2016-12-08 01:00:00  36.25               0.0            7.392779
# 2016-12-08 02:00:00  36.09               0.0            7.266433
# 2016-12-08 03:00:00  34.25               0.0            7.144611
# ...                    ...               ...                 ...
# 2020-09-30 19:00:00  46.55               0.0            9.389641
# 2020-09-30 20:00:00  40.95               0.0            9.401640
# 2020-09-30 21:00:00  34.84               0.0            9.361170
# 2020-09-30 22:00:00  37.44               0.0            9.250442
# 2020-09-30 23:00:00  31.93               0.0            9.174755
#
#                      Wind OnGeneration  Month  Day  Week  Day_of_Week  Hour
# DateTime
# 2016-12-07 23:00:00           8.466638     12    2    49            2    23
# 2016-12-08 00:00:00           8.300161     12    3    49            3     0
# 2016-12-08 01:00:00           8.231132     12    3    49            3     1
# 2016-12-08 02:00:00           8.149012     12    3    49            3     2
# 2016-12-08 03:00:00           8.020376     12    3    49            3     3
# ...                                ...    ...  ...   ...          ...   ...
# 2020-09-30 19:00:00           7.312490      9    2    40            2    19
# 2020-09-30 20:00:00           7.256017      9    2    40            2    20
# 2020-09-30 21:00:00           7.177128      9    2    40            2    21
# 2020-09-30 22:00:00           7.016053      9    2    40            2    22
# 2020-09-30 23:00:00           6.960327      9    2    40            2    23
#
# [33433 rows x 9 columns]

# %%
df_lasso_dummies ={hour: pd.DataFrame() for hour in hours}
for i in range(len(hours)):
    df_lasso_dummies[i] = df_model_dummies[df_model_dummies['Hour'] == i]

for i in range(len(hours)):
    df_lasso_dummies[i].drop(columns='Hour', inplace=True)

# Example of the dataset of 00:00    
df_lasso_dummies[0]
# Out:
#             Price  Solar Generation  Wind OffGeneration  Wind OnGeneration  \
# DateTime
# 2016-12-08  37.76               0.0            7.517084           8.300161
# 2016-12-09  40.44               0.0            5.556315           6.931569
# 2016-12-10  40.25               0.0            7.366115           8.002128
# 2016-12-11  40.93               0.0            6.666060           7.944538
# 2016-12-12  37.34               0.0            4.822199           5.824396
# ...           ...               ...                 ...                ...
# 2020-09-26  26.20               0.0            9.695505           8.391436
# 2020-09-27  16.95               0.0            9.394737           7.199829
# 2020-09-28  27.61               0.0            8.139418           5.907768
# 2020-09-29  34.37               0.0            5.552084           6.036517
# 2020-09-30  38.83               0.0            6.662200           8.057999
#
#             Month  Day  Week  Day_of_Week
# DateTime
# 2016-12-08     12    3    49            3
# 2016-12-09     12    4    49            4
# 2016-12-10     12    5    49            5
# 2016-12-11     12    6    49            6
# 2016-12-12     12    0    50            0
# ...           ...  ...   ...          ...
# 2020-09-26      9    5    39            5
# 2020-09-27      9    6    39            6
# 2020-09-28      9    0    40            0
# 2020-09-29      9    1    40            1
# 2020-09-30      9    2    40            2
#
# [1393 rows x 8 columns]

# %% [markdown]
# ## Splitting to train and test

# %%
X_train = {hour: pd.DataFrame() for hour in hours}
y_train = {hour: pd.DataFrame() for hour in hours}
X_test = {hour: pd.DataFrame() for hour in hours}
y_test = {hour: pd.DataFrame() for hour in hours}

for hour in range(len(hours)):
    X_train[hour], X_test[hour], y_train[hour], y_test[hour] = train_test_split(df_lasso_dummies[hour].drop(columns='Price'),
                                                                                df_lasso_dummies[hour]['Price'],
                                                                                test_size=0.20,
                                                                                shuffle=False)

# %% [markdown]
# ## Model Trainning

# %%
from sklearn.preprocessing import OneHotEncoder


# Create empty dataframes with hour as index in order to fill the trained models, and train them accordingly
model_train = {hour: pd.DataFrame() for hour in hours}
train_pred = {hour: pd.DataFrame() for hour in hours}
test_pred = {hour: pd.DataFrame() for hour in hours}



# We will traing every model for every hour, and we generate a data frame that will inform us about the r-squared,
# alpha value and intercept for every model

rsquared_dummies_test = []
rsquared_dummies_train = []
model_dummies_name = []


for hour in hours:
    numeric_features = ['Solar Generation', 'Wind OffGeneration', 'Wind OnGeneration']
    categorical_features = X_train[hour].drop(columns=['Solar Generation', 'Wind OffGeneration', 'Wind OnGeneration']).columns.to_list()

    numeric_transformer = Pipeline(
        steps=[("scaler", StandardScaler())]
    )

    categorical_transformer = Pipeline(
        steps=[("encoder", OneHotEncoder())]
    )

    preprocessor = ColumnTransformer(
        transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features)
        ]
    )

    lasso_with_dummies = Pipeline(
        steps=[("preprocessor", preprocessor), ("regressor", LassoCV(cv=tscv))]
    )

    model_train[hour] = lasso_with_dummies.fit(X_train[hour], y_train[hour])
    train_pred[hour] = model_train[hour].predict(X_train[hour])
    test_pred[hour] = model_train[hour].predict(X_test[hour])
    train_score = r2_score(y_train[hour], train_pred[hour])
    test_score = r2_score(y_test[hour], test_pred[hour])
    
    rsquared_dummies_train.append(train_score)
    rsquared_dummies_test.append(test_score)
    
    

    model_dummies_name.append('model[' + str(hour) + ']')

model_dummies_results = pd.DataFrame(columns=['Model', 'Rsquared Value Train', 'Rsquared Value Test'])
model_dummies_results['Model'] = model_dummies_name
model_dummies_results['Rsquared Value Train'] = rsquared_dummies_train
model_dummies_results['Rsquared Value Test'] = rsquared_dummies_test



# Table that shows the results for every trained model
model_dummies_results
# Out:
#         Model  Rsquared Value Train  Rsquared Value Test
# 0    model[0]              0.095901            -3.694069
# 1    model[1]              0.124406            -3.174464
# 2    model[2]              0.110042            -2.678019
# 3    model[3]              0.100071            -2.112621
# 4    model[4]              0.000000            -2.240057
# 5    model[5]              0.165918            -1.543571
# 6    model[6]              0.257128            -1.010894
# 7    model[7]              0.268974            -1.532372
# 8    model[8]              0.180215            -2.637239
# 9    model[9]              0.143751            -2.309174
# 10  model[10]              0.165146            -1.919759
# 11  model[11]              0.168102            -1.429424
# 12  model[12]              0.131982            -1.643382
# 13  model[13]              0.148493            -1.556776
# 14  model[14]              0.212039            -1.205329
# 15  model[15]              0.188849            -1.449466
# 16  model[16]              0.288936            -1.202017
# 17  model[17]              0.334461            -0.889309
# 18  model[18]              0.228375            -1.292811
# 19  model[19]              0.005693            -4.275269
# 20  model[20]              0.062660            -4.803084
# 21  model[21]              0.082777            -4.119530
# 22  model[22]              0.081228            -3.571629
# 23  model[23]              0.154439            -3.184822

# %%
lasso_with_dummies
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Solar Generation',
#                                                    'Wind OffGeneration',
#                                                    'Wind OnGeneration']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('encoder',
#                                                                    OneHotEncoder())]),
#                                                   ['Month', 'Day', 'Week',
#                                                    'Day_of_Week'])])),
#                 ('regressor',
#                  LassoCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None)))])

# %%
h = 5

inspection_df = pd.DataFrame()
inspection_df['Actual'] = y_test[h]
inspection_df['Predicted'] = test_pred[h]
sns.lineplot(x=inspection_df.index, y=inspection_df['Actual'])
sns.lineplot(x=inspection_df.index, y=inspection_df['Predicted'])
# Out:
# <AxesSubplot:xlabel='DateTime', ylabel='Actual'>

# %% [markdown]
# # Quantile Regression

# %%
from sklearn.model_selection import TimeSeriesSplit
import statsmodels.api as sm
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_pinball_loss

# %%
data = df_hour[1][['Price','Wind OffGeneration', 'Wind OnGeneration','Solar Generation','Price_Recent', 'Price_24', 'Price_167']]

# %%
data
# Out:
#                      Price  Wind OffGeneration  Wind OnGeneration  \
# DateTime
# 2016-12-08 01:00:00  36.25             2986.97            4590.27
# 2016-12-09 01:00:00  37.33              989.59            2440.66
# 2016-12-10 01:00:00  40.26             2705.68            4038.47
# 2016-12-11 01:00:00  38.59             2073.47            4114.45
# 2016-12-12 01:00:00  37.02              429.59            1246.44
# ...                    ...                 ...                ...
# 2020-09-26 01:00:00  23.23             8847.27            4908.71
# 2020-09-27 01:00:00  13.69             7654.24            2511.73
# 2020-09-28 01:00:00  26.77             4323.23            1391.80
# 2020-09-29 01:00:00  32.54              903.32            1175.29
# 2020-09-30 01:00:00  35.33             2381.07            4658.24
#
#                      Solar Generation  Price_Recent  Price_24  Price_167
# DateTime
# 2016-12-08 01:00:00               0.0         37.92     36.99      39.59
# 2016-12-09 01:00:00               0.0         40.87     36.25      40.48
# 2016-12-10 01:00:00               0.0         43.58     37.33      40.29
# 2016-12-11 01:00:00               0.0         42.07     40.26      38.00
# 2016-12-12 01:00:00               0.0         37.41     38.59      32.36
# ...                               ...           ...       ...        ...
# 2020-09-26 01:00:00               0.0         28.71     33.97      29.21
# 2020-09-27 01:00:00               0.0         18.77     23.23      32.00
# 2020-09-28 01:00:00               0.0         28.85     13.69      30.03
# 2020-09-29 01:00:00               0.0         36.10     26.77      35.90
# 2020-09-30 01:00:00               0.0         40.25     32.54      32.63
#
# [1393 rows x 7 columns]

# %%
tscv = TimeSeriesSplit(n_splits=5)

# %%
for train_index, test_index in tscv.split(data):
    train_data = data[:test_index[0]]
    test_data = data[test_index[0]:test_index[-1]+1]
    y = train_data['Price']
    X =  train_data.drop(columns=['Price'])
    X_test = test_data.drop(columns=['Price'])
    y_test = test_data['Price']
    gbr = GradientBoostingRegressor(loss='quantile', alpha=0.6)
    gbr_fit = gbr.fit(X, y)
    metric = mean_pinball_loss
    

y_pred = gbr_predict = gbr_fit.predict(X_test)
plt.plot(X_test.index, y_test, label='True')
plt.plot(X_test.index, y_pred, label='Predicted')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.show()
